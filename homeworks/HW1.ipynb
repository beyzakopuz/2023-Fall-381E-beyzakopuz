# %% [markdown]
# # HW1 - BEYZA KOPUZ, 090200354

# %% [markdown]
# # Q1

# %%
import wbgapi as wbg
import pandas as pd
import wbdata as wb
import json

# %%
data = pd.read_json('https://cckpapi.worldbank.org/cckp/v1/era5-x0.5_timeseries_pr,tas_timeseries_monthly_1950-2020_mean_historical_era5_era5_mean/REU,MCO,ESP,ITA,SVN,HRV,BIH,MNE,ALB,GRC,TUR,SYR,LBN,ISR,PSE,EGY,LBY,TUN,DZA,MAR,MLT,CYP?_format=json')

# %% [markdown]
# Extracting pr and tas from the data.

# %%
data
# Out:
#            metadata                                               data
# apiVersion       v1                                                NaN
# status      success                                                NaN
# messages         []                                                NaN
# pr              NaN  {'ALB': {'1950-01': 97.35, '1950-02': 87.45, '...
# tas             NaN  {'ALB': {'1950-01': 0.39, '1950-02': 4.68, '19...

# %%
data_column = data['data']

# %%
pr = data_column['pr']
tas = data_column['tas']

# %% [markdown]
# ## 1.

# %%
tas
# Out:
# {'ALB': {'1950-01': 0.39,
#   '1950-02': 4.68,
#   '1950-03': 7.35,
#   '1950-04': 11.63,
#   '1950-05': 16.16,
#   '1950-06': 20.35,
#   '1950-07': 25.01,
#   '1950-08': 23.62,
#   '1950-09': 20.08,
#   '1950-10': 13.63,
#   '1950-11': 8.56,
#   '1950-12': 6.2,
#   '1951-01': 3.43,
#   '1951-02': 5.59,
#   '1951-03': 7.27,
#   '1951-04': 11.07,
#   '1951-05': 15.72,
#   '1951-06': 19.64,
#   '1951-07': 21.95,
#   '1951-08': 23.24,
#   '1951-09': 20.07,
#   '1951-10': 11.65,
#   '1951-11': 9.44,
#   '1951-12': 4.31,
#   '1952-01': 3.1,
#   '1952-02': 2.7199999999999998,
#   '1952-03': 5.76,
#   '1952-04': 12.95,
#   '1952-05': 14.66,
#   '1952-06': 20.3,
#   '1952-07': 23.17,
#   '1952-08': 24.82,
#   '1952-09': 20.24,
#   '1952-10': 13.15,
#   '1952-11': 8.24,
#   '1952-12': 6.3,
#   '1953-01': 2.21,
#   '1953-02': 3.25,
#   '1953-03': 4.77,
#   '1953-04': 11.5,
#   '1953-05': 14.45,
#   '1953-06': 19.08,
#   '1953-07': 23.09,
#   '1953-08': 21.99,
#   '1953-09': 19.01,
#   '1953-10': 14.13,
#   '1953-11': 6.33,
#   '1953-12': 2.71,
#   '1954-01': 0.05,
#   '1954-02': 1.21,
#   '1954-03': 7.24,
#   '1954-04': 9.24,
#   '1954-05': 13.53,
#   '1954-06': 20.23,
#   '1954-07': 21.3,
#   '1954-08': 21.14,
#   '1954-09': 19.06,
#   '1954-10': 12.59,
#   '1954-11': 7.49,
#   '1954-12': 4.34,
#   '1955-01': 5.72,
#   '1955-02': 6.39,
#   '1955-03': 5.97,
#   '1955-04': 8.52,
#   '1955-05': 15.8,
#   '1955-06': 18.97,
#   '1955-07': 21.06,
#   '1955-08': 19.32,
#   '1955-09': 17.1,
#   '1955-10': 13.53,
#   '1955-11': 7.71,
#   '1955-12': 5.73,
#   '1956-01': 3.46,
#   '1956-02': -0.28,
#   '1956-03': 3.55,
#   '1956-04': 9.78,
#   '1956-05': 14.58,
#   '1956-06': 17.66,
#   '1956-07': 21.89,
#   '1956-08': 23.42,
#   '1956-09': 19.14,
#   '1956-10': 12.42,
#   '1956-11': 7.82,
#   '1956-12': 2.92,
#   '1957-01': 1.57,
#   '1957-02': 5.7,
#   '1957-03': 6.94,
#   '1957-04': 11.29,
#   '1957-05': 13.41,
#   '1957-06': 20.9,
#   '1957-07': 21.88,
#   '1957-08': 21.41,
#   '1957-09': 17.16,
#   '1957-10': 14.18,
#   '1957-11': 8.91,
#   '1957-12': 3.47,
#   '1958-01': 2.6,
#   '1958-02': 5.5600000000000005,
#   '1958-03': 4.48,
#   '1958-04': 8.92,
#   '1958-05': 16.6,
#   '1958-06': 18.73,
#   '1958-07': 21.74,
#   '1958-08': 22.79,
#   '1958-09': 17.28,
#   '1958-10': 12.56,
#   '1958-11': 9.21,
#   '1958-12': 6.57,
#   '1959-01': 1.09,
#   '1959-02': 2.16,
#   '1959-03': 9.07,
#   '1959-04': 10.75,
#   '1959-05': 14.71,
#   '1959-06': 17.56,
#   '1959-07': 20.79,
#   '1959-08': 20.13,
#   '1959-09': 15.98,
#   '1959-10': 10.71,
#   '1959-11': 7.76,
#   '1959-12': 6.32,
#   '1960-01': 2.91,
#   '1960-02': 4.3,
#   '1960-03': 6.84,
#   '1960-04': 10.57,
#   '1960-05': 14.96,
#   '1960-06': 19.22,
#   '1960-07': 20.64,
#   '1960-08': 22.3,
#   '1960-09': 17.27,
#   '1960-10': 14.69,
#   '1960-11': 10.07,
#   '1960-12': 6.92,
#   '1961-01': 2.59,
#   '1961-02': 3.08,
#   '1961-03': 8.01,
#   '1961-04': 12.85,
#   '1961-05': 14.43,
#   '1961-06': 19.02,
#   '1961-07': 21.22,
#   '1961-08': 21.98,
#   '1961-09': 19.02,
#   '1961-10': 14.04,
#   '1961-11': 10.04,
#   '1961-12': 4.67,
#   '1962-01': 4.53,
#   '1962-02': 1.44,
#   '1962-03': 5.8,
#   '1962-04': 10.99,
#   '1962-05': 15.63,
#   '1962-06': 18.45,
#   '1962-07': 22.06,
#   '1962-08': 23.9,
#   '1962-09': 18.97,
#   '1962-10': 14.11,
#   '1962-11': 9.77,
#   '1962-12': 1.88,
#   '1963-01': 0.18,
#   '1963-02': 3.54,
#   '1963-03': 4.53,
#   '1963-04': 10.31,
#   '1963-05': 14.49,
#   '1963-06': 18.76,
#   '1963-07': 22,
#   '1963-08': 22.11,
#   '1963-09': 18.8,
#   '1963-10': 12.52,
#   '1963-11': 10.38,
#   '1963-12': 5.38,
#   '1964-01': 0.89,
#   '1964-02': 3.01,
#   '1964-03': 7.49,
#   '1964-04': 10.36,
#   '1964-05': 14.41,
#   '1964-06': 19.43,
#   '1964-07': 20.33,
#   '1964-08': 20.22,
#   '1964-09': 16.87,
#   '1964-10': 13.4,
#   '1964-11': 8.8,
#   '1964-12': 3.9,
#   '1965-01': 2.42,
#   '1965-02': -0.59,
#   '1974-04': 9.7,
#   '1974-05': 13.62,
#   '1974-06': 18.13,
#   '1974-07': 21.14,
#   '1974-08': 22.26,
#   '1974-09': 18.54,
#   '1974-10': 12.11,
#   '1974-11': 7.48,
#   '1974-12': 3.5700000000000003,
#   '1975-01': 2.15,
#   '1975-02': 2.86,
#   '1975-03': 8.18,
#   '1975-04': 11,
#   '1975-05': 15.56,
#   '1975-06': 18.28,
#   '1975-07': 20.77,
#   '1975-08': 20.2,
#   '1975-09': 19.68,
#   '1975-10': 12.39,
#   '1975-11': 7.48,
#   '1975-12': 4.04,
#   '1976-01': 2.96,
#   '1976-02': 4.18,
#   '1976-03': 6.2,
#   '1976-04': 10.33,
#   '1976-05': 15.2,
#   '1976-06': 17.98,
#   '1976-07': 20.01,
#   '1976-08': 17.84,
#   '1976-09': 15.61,
#   '1976-10': 14.07,
#   '1976-11': 8.04,
#   '1976-12': 4.02,
#   '1977-01': 3.6,
#   '1977-02': 7.66,
#   '1977-03': 9.23,
#   '1977-04': 10.6,
#   '1977-05': 16.14,
#   '1977-06': 18.51,
#   '1977-07': 21.93,
#   '1977-08': 21.13,
#   '1977-09': 16.62,
#   '1977-10': 12.51,
#   '1977-11': 9.61,
#   '1977-12': 2.54,
#   '1978-01': 2.37,
#   '1978-02': 5.3,
#   '1978-03': 7.33,
#   '1978-04': 9.73,
#   '1978-05': 13.94,
#   '1978-06': 18.65,
#   '1978-07': 20.86,
#   '1978-08': 20.38,
#   '1978-09': 15.54,
#   '1978-10': 12.05,
#   '1978-11': 4.89,
#   '1978-12': 5.94,
#   '1979-01': 1.38,
#   '1979-02': 5.53,
#   '1979-03': 8.2,
#   '1979-04': 9.19,
#   '1979-05': 15.16,
#   '1979-06': 19.64,
#   '1979-07': 20.59,
#   '1979-08': 19.74,
#   '1979-09': 17.31,
#   '1979-10': 13.25,
#   '1979-11': 8.55,
#   '1979-12': 5.96,
#   '1980-01': 0.93,
#   '1980-02': 4.02,
#   '1980-03': 6.71,
#   '1980-04': 8.78,
#   '1980-05': 12.97,
#   '1980-06': 17.88,
#   '1980-07': 20.72,
#   '1980-08': 21.69,
#   '1980-09': 18,
#   '1980-10': 13.72,
#   '1980-11': 9.74,
#   '1980-12': 2.5300000000000002,
#   '1981-01': 0.14,
#   '1981-02': 3.17,
#   '1981-03': 8.69,
#   '1981-04': 11.1,
#   '1981-05': 14.22,
#   '1981-06': 20.05,
#   '1981-07': 20.27,
#   '1981-08': 20.82,
#   '1981-09': 17.74,
#   '1981-10': 14.33,
#   '1981-11': 4.68,
#   '1981-12': 5.02,
#   '1982-01': 3.64,
#   '1982-02': 2.81,
#   '1982-03': 5.99,
#   '1982-04': 9.8,
#   '1982-05': 15.63,
#   '1982-06': 20.27,
#   '1982-07': 21.35,
#   '1982-08': 21.58,
#   '1982-09': 20,
#   '1982-10': 13.99,
#   '1982-11': 7.61,
#   '1982-12': 5.91,
#   '1983-01': 2.94,
#   '1983-02': 1.81,
#   '1983-03': 7.47,
#   '1983-04': 11.84,
#   '1992-05': 15.07,
#   '1992-06': 17.9,
#   '1992-07': 20.69,
#   '1992-08': 23.58,
#   '1992-09': 18.14,
#   '1992-10': 14.85,
#   '1992-11': 9.2,
#   '1992-12': 2.81,
#   '1993-01': 1.43,
#   '1993-02': 1.72,
#   '1993-03': 5,
#   '1993-04': 10.67,
#   '1993-05': 15.74,
#   '1993-06': 19.79,
#   '1993-07': 21.2,
#   '1993-08': 22.77,
#   '1993-09': 17.76,
#   '1993-10': 15.3,
#   '1993-11': 7.43,
#   '1993-12': 6.07,
#   '1994-01': 5.02,
#   '1994-02': 4.32,
#   '1994-03': 9.06,
#   '1994-04': 11,
#   '1994-05': 16.35,
#   '1994-06': 19.1,
#   '1994-07': 22.65,
#   '1994-08': 23.32,
#   '1994-09': 20.22,
#   '1994-10': 14.21,
#   '1994-11': 8.67,
#   '1994-12': 3.94,
#   '1995-01': 2.59,
#   '1995-02': 6.41,
#   '1995-03': 6.19,
#   '1995-04': 9.29,
#   '1995-05': 14.4,
#   '1995-06': 18.91,
#   '1995-07': 22.38,
#   '1995-08': 19.98,
#   '1995-09': 16.42,
#   '1995-10': 12.77,
#   '1995-11': 5.41,
#   '1995-12': 6.49,
#   '1996-01': 3.96,
#   '1996-02': 3.01,
#   '1996-03': 3.93,
#   '1996-04': 10.17,
#   '1996-05': 16.16,
#   '1996-06': 20.04,
#   '1996-07': 21.41,
#   '1996-08': 21.63,
#   '1996-09': 15.24,
#   '1996-10': 12.36,
#   '1996-11': 9.46,
#   '1996-12': 5.26,
#   '1997-01': 5.03,
#   '1997-02': 5.01,
#   '1997-03': 6.75,
#   '1997-04': 6.55,
#   '1997-05': 15.96,
#   '1997-06': 20.43,
#   '1997-07': 21.32,
#   '1997-08': 20.29,
#   '1997-09': 18.52,
#   '1997-10': 11.37,
#   '1997-11': 8.95,
#   '1997-12': 4.77,
#   '1998-01': 4.68,
#   '1998-02': 5.82,
#   '1998-03': 4.93,
#   '1998-04': 11.62,
#   '1998-05': 15.17,
#   '1998-06': 20.12,
#   '1998-07': 22.76,
#   '1998-08': 23.56,
#   '1998-09': 17.39,
#   '1998-10': 14.03,
#   '1998-11': 7.21,
#   '1998-12': 1.27,
#   '1999-01': 3.18,
#   '1999-02': 1.88,
#   '1999-03': 6.91,
#   '1999-04': 10.94,
#   '1999-05': 16.66,
#   '1999-06': 20.17,
#   '1999-07': 21.97,
#   '1999-08': 22.98,
#   '1999-09': 18.95,
#   '1999-10': 14.56,
#   '1999-11': 8.73,
#   '1999-12': 5.71,
#   '2000-01': -1.26,
#   '2000-02': 3.71,
#   '2000-03': 5.57,
#   '2000-04': 12.57,
#   '2000-05': 16.79,
#   '2000-06': 20.32,
#   '2000-07': 21.74,
#   '2000-08': 22.8,
#   '2000-09': 17.61,
#   '2000-10': 14.15,
#   '2000-11': 10.88,
#   '2000-12': 5.59,
#   '2001-01': 5.6,
#   '2001-02': 4.93,
#   '2001-03': 10.44,
#   '2001-04': 9.95,
#   '2001-05': 16.45,
#   '2001-06': 18.7,
#   '2001-07': 22.19,
#   '2001-08': 23.28,
#   '2001-09': 16.85,
#   '2001-10': 14.7,
#   '2001-11': 7.37,
#   '2001-12': -0.59,
#   '2002-01': 1.35,
#   '2002-02': 6.93,
#   '2002-03': 9.1,
#   '2002-04': 10.94,
#   '2002-05': 15.81,
#   '2002-06': 20.49,
#   '2002-07': 22.25,
#   '2002-08': 20.42,
#   '2002-09': 15.92,
#   '2002-10': 12.81,
#   '2002-11': 9.7,
#   '2002-12': 5.14,
#   '2003-01': 4.73,
#   '2003-02': -0.19,
#   '2003-03': 5.99,
#   '2003-04': 9.51,
#   '2003-05': 18.22,
#   '2003-06': 22.22,
#   '2003-07': 23.17,
#   '2003-08': 23.96,
#   '2003-09': 17.3,
#   '2003-10': 13.04,
#   '2003-11': 10.04,
#   '2003-12': 3.9699999999999998,
#   '2004-01': 1.77,
#   '2004-02': 4.05,
#   '2004-03': 6.96,
#   '2004-04': 11.79,
#   '2004-05': 13.34,
#   '2004-06': 19.19,
#   '2004-07': 21.89,
#   '2004-08': 20.83,
#   '2004-09': 17.69,
#   '2004-10': 14.92,
#   '2004-11': 7.92,
#   '2004-12': 5.8100000000000005,
#   '2005-01': 2.3,
#   '2005-02': 1.29,
#   '2005-03': 6.25,
#   '2005-04': 10.29,
#   '2005-05': 16.08,
#   '2005-06': 18.66,
#   '2005-07': 21.82,
#   '2005-08': 20.47,
#   '2005-09': 17.91,
#   '2005-10': 12.63,
#   '2005-11': 6.97,
#   '2005-12': 3.83,
#   '2006-01': 0.41000000000000003,
#   '2006-02': 2.75,
#   '2006-03': 6.54,
#   '2006-04': 11.77,
#   '2006-05': 15.63,
#   '2006-06': 18.85,
#   '2006-07': 21.83,
#   '2006-08': 20.9,
#   '2006-09': 18.04,
#   '2006-10': 14.11,
#   '2006-11': 6.47,
#   '2006-12': 4.24,
#   '2007-01': 5.01,
#   '2007-02': 6.08,
#   '2007-03': 8.42,
#   '2007-04': 12.07,
#   '2007-05': 16.42,
#   '2007-06': 20.9,
#   '2007-07': 23.79,
#   '2007-08': 22.97,
#   '2007-09': 16.57,
#   '2007-10': 12.94,
#   '2007-11': 6.95,
#   '2007-12': 2.69,
#   '2008-01': 3.47,
#   '2008-02': 4.51,
#   '2008-03': 7.99,
#   '2008-04': 11.02,
#   '2008-05': 15.75,
#   '2008-06': 19.85,
#   '2008-07': 22.15,
#   '2008-08': 22.97,
#   '2008-09': 16.95,
#   '2008-10': 13.61,
#   '2008-11': 9.64,
#   '2008-12': 5.05,
#   '2009-01': 3.99,
#   '2009-02': 3.1,
#   '2009-03': 6.24,
#   '2009-04': 12.09,
#   '2009-05': 16.82,
#   '2009-06': 18.88,
#   '2009-07': 22.23,
#   '2009-08': 22.67,
#   '2009-09': 18.76,
#   '2009-10': 12.84,
#   '2009-11': 9.06,
#   '2009-12': 6.95,
#   '2010-01': 3.75,
#   '2010-02': 4.69,
#   '2010-03': 7.16,
#   '2010-04': 11.97,
#   '2010-05': 15.4,
#   '2010-06': 19.17,
#   '2010-07': 21.89,
#   '2010-08': 22.92,
#   '2010-09': 17.31,
#   '2010-10': 12.32,
#   '2010-11': 11.28,
#   '2010-12': 4.94,
#   '2011-01': 3.15,
#   '2011-02': 4.74,
#   '2011-03': 7.37,
#   '2011-04': 11.62,
#   '2011-05': 15.15,
#   '2011-06': 19.63,
#   '2011-07': 21.82,
#   '2011-08': 23.03,
#   '2011-09': 20.95,
#   '2011-10': 12.14,
#   '2011-11': 6.92,
#   '2011-12': 4.68,
#   '2012-01': 0.65,
#   '2012-02': 1.53,
#   '2012-03': 8.36,
#   '2012-04': 11.37,
#   '2012-05': 15.24,
#   '2012-06': 21.65,
#   '2012-07': 24.61,
#   '2012-08': 23.68,
#   '2012-09': 19.76,
#   '2012-10': 15.28,
#   '2012-11': 10.8,
#   '2012-12': 3.39,
#   '2013-01': 4.22,
#   '2013-02': 5.26,
#   '2013-03': 8.12,
#   '2013-04': 13.02,
#   '2013-05': 16.42,
#   '2013-06': 19.27,
#   '2013-07': 22.11,
#   '2013-08': 23.19,
#   '2013-09': 17.85,
#   '2013-10': 14.21,
#   '2013-11': 10.12,
#   '2013-12': 4.08,
#   '2014-01': 6.27,
#   '2014-02': 7.59,
#   '2014-03': 8.77,
#   '2014-04': 10.99,
#   '2014-05': 14.54,
#   '2014-06': 19.32,
#   '2014-07': 20.9,
#   '2014-08': 22.01,
#   '2014-09': 17.3,
#   '2014-10': 13.69,
#   '2014-11': 10.44,
#   '2014-12': 5.6,
#   '2015-01': 3.26,
#   '2015-02': 3.98,
#   '2015-03': 7.25,
#   '2015-04': 10.76,
#   '2015-05': 16.85,
#   '2015-06': 19.49,
#   '2015-07': 24.45,
#   '2015-08': 23.28,
#   '2015-09': 20.05,
#   '2015-10': 14.25,
#   '2015-11': 10.19,
#   '2015-12': 4.64,
#   '2016-01': 3.89,
#   '2016-02': 8.97,
#   '2016-03': 8.18,
#   '2016-04': 13.87,
#   '2016-05': 14.72,
#   '2016-06': 20.41,
#   '2016-07': 22.84,
#   '2016-08': 22.04,
#   '2016-09': 17.82,
#   '2016-10': 13.72,
#   '2016-11': 8.68,
#   '2016-12': 2.75,
#   '2017-01': 0.05,
#   '2017-02': 6.92,
#   '2017-03': 9.94,
#   '2017-04': 11.19,
#   '2017-05': 15.69,
#   '2017-06': 21.46,
#   '2017-07': 23.76,
#   '2017-08': 24.18,
#   '2017-09': 17.59,
#   '2017-10': 12.92,
#   '2017-11': 8.53,
#   '2017-12': 4.9,
#   '2018-01': 4.85,
#   '2018-02': 5,
#   '2018-03': 8.35,
#   '2018-04': 15.05,
#   '2018-05': 17.54,
#   '2018-06': 19.67,
#   '2018-07': 22.07,
#   '2018-08': 22.67,
#   '2018-09': 19.08,
#   '2018-10': 15.45,
#   '2018-11': 10.24,
#   '2018-12': 4.21,
#   '2019-01': 1.15,
#   '2019-02': 5.31,
#   '2019-03': 9.67,
#   '2019-04': 11.88,
#   '2019-05': 13.5,
#   '2019-06': 21.4,
#   '2019-07': 22.44,
#   '2019-08': 23.96,
#   '2019-09': 19.39,
#   '2019-10': 15.44,
#   '2019-11': 11.78,
#   '2019-12': 6.41,
#   '2020-01': 3.63,
#   '2020-02': 6.22,
#   '2020-03': 8.37,
#   '2020-04': 11.2,
#   '2020-05': 16.04,
#   '2020-06': 18.5,
#   '2020-07': 22.68,
#   '2020-08': 23.05,
#   '2020-09': 20.25,
#   '2020-10': 13.81,
#   '2020-11': 8.99,
#   '2020-12': 7.46},
#  'BIH': {'1950-01': -3.92,
#   '1950-02': 1.3599999999999999,
#   '1950-03': 4.82,
#   '1950-04': 9.19,
#   '1950-05': 14.71,
#   '1950-06': 19.53,
#   '1950-07': 23.06,
#   '1950-08': 22.04,
#   '1950-09': 17.23,
#   '1950-10': 9.78,
#   '1950-11': 5.51,
#   '1950-12': 2.65,
#   '1951-01': 1.1400000000000001,
#   '1951-02': 3.48,
#   '1951-03': 4.32,
#   '1951-04': 8.47,
#   '1951-05': 13.87,
#   '1951-06': 17.28,
#   '1951-07': 18.76,
#   '1951-08': 20.03,
#   '1951-09': 17.26,
#   '1951-10': 8.34,
#   '1951-11': 7.06,
#   '1951-12': 1.9100000000000001,
#   '1952-01': -1.15,
#   '1952-02': -0.72,
#   '1952-03': 2.7,
#   '1952-04': 11.58,
#   '1952-05': 12.46,
#   '1952-06': 17.63,
#   '1952-07': 20.81,
#   '1952-08': 22.19,
#   '1952-09': 15.41,
#   '1952-10': 10.07,
#   '1952-11': 3.87,
#   '1952-12': 1.05,
#   '1953-01': -1.55,
#   '1953-02': -1.33,
#   '1953-03': 2.02,
#   '1953-04': 9.95,
#   '1953-05': 12.62,
#   '1953-06': 17.53,
#   '1953-07': 20.36,
#   '1953-08': 17.91,
#   '1953-09': 15.93,
#   '1953-10': 11.63,
#   '1953-11': 3.17,
#   '1953-12': 0.61,
#   '1954-01': -6.01,
#   '1954-02': -5.19,
#   '1954-03': 5.17,
#   '1954-04': 6.97,
#   '1954-05': 12.37,
#   '1954-06': 18.7,
#   '1954-07': 18.11,
#   '1954-08': 18.72,
#   '1954-09': 16.56,
#   '1954-10': 9.02,
#   '1954-11': 3.81,
#   '1954-12': 1.85,
#   '1955-01': 1.8399999999999999,
#   '1955-02': 2.39,
#   '1955-03': 2.37,
#   '1955-04': 6.08,
#   '1955-05': 13.17,
#   '1955-06': 16.54,
#   '1955-07': 18.28,
#   '1955-08': 16.8,
#   '1955-09': 14.15,
#   '1955-10': 9.86,
#   '1955-11': 3.5300000000000002,
#   '1955-12': 3.43,
#   '1956-01': 0.41000000000000003,
#   '1956-02': -8.68,
#   '1956-03': 0.25,
#   '1956-04': 8.28,
#   '1956-05': 13.15,
#   '1956-06': 15.55,
#   '1956-07': 19.38,
#   '1956-08': 20.05,
#   '1956-09': 16.39,
#   '1956-10': 9.58,
#   '1956-11': 2.45,
#   '1956-12': -1.6600000000000001,
#   '1957-01': -2.92,
#   '1957-02': 3.4,
#   '1957-03': 5.98,
#   '1957-04': 8.85,
#   '1957-05': 11.03,
#   '1957-06': 18.93,
#   '1957-07': 19.63,
#   '1957-08': 18.28,
#   '1957-09': 14.31,
#   '1957-10': 10.01,
#   '1957-11': 5.68,
#   '1957-12': 0.14,
#   '1958-01': -1.53,
#   '1958-02': 3.3,
#   '1958-03': -0.35000000000000003,
#   '1958-04': 6.09,
#   '1958-05': 16.55,
#   '1958-06': 16.63,
#   '1958-07': 19.95,
#   '1958-08': 19.81,
#   '1958-09': 14.6,
#   '1958-10': 10.3,
#   '1958-11': 6.29,
#   '1958-12': 4.23,
#   '1959-01': -0.92,
#   '1959-02': -2.19,
#   '1959-03': 7.6,
#   '1959-04': 9.4,
#   '1959-05': 13.32,
#   '1959-06': 16.08,
#   '1959-07': 19.16,
#   '1959-08': 17.46,
#   '1959-09': 13.27,
#   '1959-10': 8.39,
#   '1959-11': 5.36,
#   '1959-12': 4.49,
#   '1960-01': -1.79,
#   '1960-02': 1.49,
#   '1960-03': 5.69,
#   '1960-04': 8.83,
#   '1960-05': 12.63,
#   '1960-06': 17.07,
#   '1960-07': 17.26,
#   '1960-08': 19.25,
#   '1960-09': 14.19,
#   '1960-10': 12.39,
#   '1960-11': 7.5,
#   '1960-12': 4.03,
#   '1961-01': -1,
#   '1961-02': 1.62,
#   '1961-03': 6.18,
#   '1961-04': 12.23,
#   '1961-05': 12.32,
#   '1961-06': 17.6,
#   '1961-07': 18.08,
#   '1961-08': 18.8,
#   '1961-09': 16.83,
#   '1961-10': 12.05,
#   '1961-11': 6.61,
#   '1961-12': -0.16,
#   '1962-01': 0.24,
#   '1962-02': -1.26,
#   '1962-03': 1.13,
#   '1962-04': 9.49,
#   '1962-05': 13.85,
#   '1962-06': 15.64,
#   '1962-07': 18.59,
#   '1962-08': 21.25,
#   '1962-09': 15.42,
#   '1962-10': 10.69,
#   '1962-11': 5.51,
#   '1962-12': -3.17,
#   '1963-01': -6.68,
#   '1963-02': -2.74,
#   '1963-03': 1.58,
#   '1963-04': 9.1,
#   '1963-05': 12.95,
#   '1963-06': 17.56,
#   '1963-07': 19.28,
#   '1963-08': 19.42,
#   '1963-09': 15.96,
#   '1963-10': 9.01,
#   '1963-11': 8.67,
#   '1963-12': -2.02,
#   '1964-01': -6.11,
#   '1964-02': -1.16,
#   '1964-03': 3.17,
#   '1964-04': 9.02,
#   '1964-05': 12.61,
#   '1964-06': 17.88,
#   '1964-07': 17.6,
#   '1964-08': 16.84,
#   '1964-09': 13.67,
#   '1964-10': 10.31,
#   '1964-11': 5.79,
#   '1964-12': 0.5,
#   '1965-01': -0.64,
#   '1965-02': -5.19,
#   '1965-03': 3.55,
#   '1965-04': 6.73,
#   '1965-05': 11.74,
#   '1965-06': 16.49,
#   '1965-07': 19.18,
#   '1965-08': 17,
#   '1965-09': 15.28,
#   '1965-10': 9.45,
#   '1965-11': 4.96,
#   '1965-12': 1.8399999999999999,
#   '1966-01': -4.2,
#   '1966-02': 4.89,
#   '1966-03': 2.31,
#   '1966-04': 9.87,
#   '1966-05': 13.09,
#   '1966-06': 16.57,
#   '1975-07': 18.54,
#   '1975-08': 17.33,
#   '1975-09': 17.09,
#   '1975-10': 9.22,
#   '1975-11': 3.88,
#   '1975-12': 1.57,
#   '1976-01': -0.51,
#   '1976-02': -0.11,
#   '1976-03': 1.48,
#   '1976-04': 8.4,
#   '1976-05': 13.22,
#   '1976-06': 15.62,
#   '1976-07': 18.39,
#   '1976-08': 15.01,
#   '1976-09': 13.17,
#   '1976-10': 11.15,
#   '1976-11': 5.51,
#   '1976-12': 0.65,
#   '1977-01': 1.98,
#   '1977-02': 4.73,
#   '1977-03': 7.91,
#   '1977-04': 8.08,
#   '1977-05': 14.03,
#   '1977-06': 16.75,
#   '1977-07': 18.74,
#   '1977-08': 18.08,
#   '1977-09': 12.74,
#   '1977-10': 10.5,
#   '1977-11': 5.66,
#   '1977-12': -1.78,
#   '1978-01': -0.44,
#   '1978-02': 0.35000000000000003,
#   '1978-03': 5.06,
#   '1978-04': 7.75,
#   '1978-05': 11.61,
#   '1978-06': 16.27,
#   '1978-07': 17.74,
#   '1978-08': 17.51,
#   '1978-09': 13.17,
#   '1978-10': 9.02,
#   '1978-11': 1.98,
#   '1978-12': 1.69,
#   '1979-01': -2.32,
#   '1979-02': 2.25,
#   '1979-03': 6.54,
#   '1979-04': 7.15,
#   '1979-05': 13.82,
#   '1979-06': 18.46,
#   '1979-07': 17.6,
#   '1979-08': 17.16,
#   '1979-09': 14.68,
#   '1979-10': 9.1,
#   '1979-11': 5.29,
#   '1979-12': 3.68,
#   '1980-01': -2.59,
#   '1980-02': 1.37,
#   '1980-03': 4.33,
#   '1980-04': 5.91,
#   '1980-05': 10.84,
#   '1980-06': 16.24,
#   '1980-07': 18.06,
#   '1980-08': 18.68,
#   '1980-09': 14.99,
#   '1980-10': 10.45,
#   '1980-11': 4.59,
#   '1980-12': -1.6800000000000002,
#   '1981-01': -4.3,
#   '1981-02': -0.78,
#   '1981-03': 7.04,
#   '1981-04': 8.98,
#   '1981-05': 13.46,
#   '1981-06': 17.63,
#   '1981-07': 17.83,
#   '1981-08': 18.28,
#   '1981-09': 15.4,
#   '1981-10': 11.75,
#   '1981-11': 2.46,
#   '1981-12': 0.75,
#   '1982-01': -1.21,
#   '1982-02': -0.72,
#   '1982-03': 3.59,
#   '1982-04': 6.55,
#   '1982-05': 14.28,
#   '1982-06': 18.36,
#   '1982-07': 19.2,
#   '1982-08': 18.81,
#   '1982-09': 18.07,
#   '1982-10': 11.35,
#   '1982-11': 5.03,
#   '1982-12': 3.33,
#   '1983-01': 1.34,
#   '1983-02': -1.62,
#   '1983-03': 5.57,
#   '1983-04': 10.94,
#   '1983-05': 15.3,
#   '1983-06': 16.1,
#   '1983-07': 20.13,
#   '1983-08': 18.51,
#   '1983-09': 14.9,
#   '1983-10': 9.63,
#   '1983-11': 2.16,
#   '1983-12': 0.1,
#   '1984-01': 0.2,
#   '1984-02': -0.33,
#   '1984-03': 3.25,
#   '1984-04': 7.87,
#   '1984-05': 12.91,
#   '1984-06': 15.72,
#   '1984-07': 17.87,
#   '1993-07': 18.89,
#   '1993-08': 19.68,
#   '1993-09': 14.87,
#   '1993-10': 11.65,
#   '1993-11': 2.12,
#   '1993-12': 2.24,
#   '1994-01': 1.25,
#   '1994-02': 0.06,
#   '1994-03': 7.35,
#   '1994-04': 8.83,
#   '1994-05': 14.23,
#   '1994-06': 17.31,
#   '1994-07': 20.33,
#   '1994-08': 21.05,
#   '1994-09': 17.74,
#   '1994-10': 9.56,
#   '1994-11': 6.77,
#   '1994-12': 1.79,
#   '1995-01': -1.34,
#   '1995-02': 4.27,
#   '1995-03': 3.56,
#   '1995-04': 8.37,
#   '1995-05': 13.05,
#   '1995-06': 16.44,
#   '1995-07': 20.8,
#   '1995-08': 17.69,
#   '1995-09': 13.63,
#   '1995-10': 10.93,
#   '1995-11': 2.61,
#   '1995-12': 2.22,
#   '1996-01': -0.11,
#   '1996-02': -2.48,
#   '1996-03': 0.7000000000000001,
#   '1996-04': 8.46,
#   '1996-05': 15.02,
#   '1996-06': 18.16,
#   '1996-07': 18.36,
#   '1996-08': 18.88,
#   '1996-09': 11.88,
#   '1996-10': 10.07,
#   '1996-11': 6.82,
#   '1996-12': -0.5,
#   '1997-01': 0.9,
#   '1997-02': 2.58,
#   '1997-03': 4.84,
#   '1997-04': 4.62,
#   '1997-05': 14.44,
#   '1997-06': 18.29,
#   '1997-07': 18.55,
#   '1997-08': 17.99,
#   '1997-09': 15.04,
#   '1997-10': 8,
#   '1997-11': 6.07,
#   '1997-12': 2.17,
#   '1998-01': 1.82,
#   '1998-02': 2.94,
#   '1998-03': 2.93,
#   '1998-04': 10.4,
#   '1998-05': 13.39,
#   '1998-06': 18.75,
#   '1998-07': 20.66,
#   '1998-08': 20.28,
#   '1998-09': 14.71,
#   '1998-10': 11.38,
#   '1998-11': 2.7800000000000002,
#   '1998-12': -3.11,
#   '1999-01': 0.45,
#   '1999-02': -0.67,
#   '1999-03': 5.58,
#   '1999-04': 9.94,
#   '1999-05': 15.12,
#   '1999-06': 18.01,
#   '1999-07': 19.42,
#   '1999-08': 19.84,
#   '1999-09': 16.81,
#   '1999-10': 11.18,
#   '1999-11': 4.14,
#   '1999-12': 1.08,
#   '2000-01': -2.85,
#   '2000-02': 1.82,
#   '2000-03': 4.74,
#   '2000-04': 11.93,
#   '2000-05': 15.87,
#   '2000-06': 18.91,
#   '2000-07': 19.54,
#   '2000-08': 21.65,
#   '2000-09': 15.18,
#   '2000-10': 12.57,
#   '2000-11': 9.12,
#   '2000-12': 3.47,
#   '2001-01': 2.75,
#   '2001-02': 2.54,
#   '2001-03': 9,
#   '2001-04': 8.63,
#   '2001-05': 15.36,
#   '2001-06': 16.17,
#   '2001-07': 19.84,
#   '2001-08': 20.55,
#   '2001-09': 13.26,
#   '2001-10': 13.01,
#   '2001-11': 3.06,
#   '2001-12': -3.2,
#   '2002-01': -1.29,
#   '2002-02': 5.12,
#   '2002-03': 7.49,
#   '2002-04': 9.18,
#   '2002-05': 15.5,
#   '2002-06': 19.07,
#   '2002-07': 20.27,
#   '2002-08': 18.83,
#   '2002-09': 13.67,
#   '2002-10': 10.9,
#   '2002-11': 8.78,
#   '2002-12': 1.82,
#   '2003-01': -0.44,
#   '2003-02': -3.51,
#   '2003-03': 4.71,
#   '2003-04': 8.51,
#   '2003-05': 17.12,
#   '2003-06': 21.06,
#   '2003-07': 20.78,
#   '2003-08': 22.6,
#   '2003-09': 14.63,
#   '2003-10': 8.97,
#   '2003-11': 7.67,
#   '2003-12': 1.24,
#   '2004-01': -1.28,
#   '2004-02': 1.53,
#   '2004-03': 4.46,
#   '2004-04': 10.26,
#   '2004-05': 12.28,
#   '2004-06': 17.54,
#   '2004-07': 19.87,
#   '2004-08': 19.32,
#   '2004-09': 14.89,
#   '2004-10': 13.22,
#   '2004-11': 4.94,
#   '2004-12': 2.69,
#   '2005-01': -0.39,
#   '2005-02': -2.83,
#   '2005-03': 2.88,
#   '2005-04': 9.27,
#   '2005-05': 14.67,
#   '2005-06': 17.12,
#   '2005-07': 19.7,
#   '2005-08': 17.68,
#   '2005-09': 15.55,
#   '2005-10': 10.66,
#   '2005-11': 4.85,
#   '2005-12': 0.72,
#   '2006-01': -1.74,
#   '2006-02': 0.65,
#   '2006-03': 3.83,
#   '2006-04': 10.52,
#   '2006-05': 14.28,
#   '2006-06': 17.47,
#   '2006-07': 20.3,
#   '2006-08': 17.88,
#   '2006-09': 16.11,
#   '2006-10': 12.22,
#   '2006-11': 5.96,
#   '2006-12': 2.62,
#   '2007-01': 4.2,
#   '2007-02': 5.2,
#   '2007-03': 7.12,
#   '2007-04': 11.81,
#   '2007-05': 15.6,
#   '2007-06': 19.7,
#   '2007-07': 21.69,
#   '2007-08': 20.73,
#   '2007-09': 13.31,
#   '2007-10': 9.27,
#   '2007-11': 3.04,
#   '2007-12': -0.29,
#   '2008-01': 2.19,
#   '2008-02': 3.75,
#   '2008-03': 5.85,
#   '2008-04': 10.18,
#   '2008-05': 15.24,
#   '2008-06': 19.02,
#   '2008-07': 19.96,
#   '2008-08': 20.4,
#   '2008-09': 14.01,
#   '2008-10': 11.85,
#   '2008-11': 6.5,
#   '2008-12': 2.9699999999999998,
#   '2009-01': -0.89,
#   '2009-02': 0.75,
#   '2009-03': 4.8100000000000005,
#   '2009-04': 11.85,
#   '2009-05': 16.13,
#   '2009-06': 17.43,
#   '2009-07': 20.81,
#   '2009-08': 20.8,
#   '2009-09': 16.9,
#   '2009-10': 9.77,
#   '2009-11': 7.23,
#   '2009-12': 2.7,
#   '2010-01': -0.30000000000000004,
#   '2010-02': 1.22,
#   '2010-03': 4.89,
#   '2010-04': 10.19,
#   '2010-05': 13.99,
#   '2010-06': 18.12,
#   '2010-07': 20.76,
#   '2010-08': 20.53,
#   '2010-09': 14.6,
#   '2010-10': 8.67,
#   '2010-11': 8.38,
#   '2010-12': 0.7000000000000001,
#   '2011-01': 0.43,
#   '2011-02': 0.79,
#   '2011-03': 5.03,
#   '2011-04': 10.95,
#   '2011-05': 13.97,
#   '2011-06': 18.51,
#   '2011-07': 20.38,
#   '2011-08': 21.51,
#   '2011-09': 19.09,
#   '2011-10': 9.7,
#   '2011-11': 4.08,
#   '2011-12': 2.6,
#   '2012-01': -0.53,
#   '2012-02': -4.3,
#   '2012-03': 7.1,
#   '2012-04': 9.93,
#   '2012-05': 13.75,
#   '2012-06': 20.44,
#   '2012-07': 22.64,
#   '2012-08': 22.46,
#   '2012-09': 17.47,
#   '2012-10': 12.03,
#   '2012-11': 8.76,
#   '2012-12': 0.28,
#   '2013-01': 1.99,
#   '2013-02': 1.49,
#   '2013-03': 4.57,
#   '2013-04': 11.55,
#   '2013-05': 14.37,
#   '2013-06': 17.69,
#   '2013-07': 20.31,
#   '2013-08': 21.17,
#   '2013-09': 15.25,
#   '2013-10': 12.46,
#   '2013-11': 7.07,
#   '2013-12': 2.02,
#   '2014-01': 4.45,
#   '2014-02': 5.98,
#   '2014-03': 7.76,
#   '2014-04': 10.46,
#   '2014-05': 13.33,
#   '2014-06': 17.7,
#   '2014-07': 19.26,
#   '2014-08': 19.19,
#   '2014-09': 15.01,
#   '2014-10': 12,
#   '2014-11': 8.47,
#   '2014-12': 2.87,
#   '2015-01': 1.3599999999999999,
#   '2015-02': 1.34,
#   '2015-03': 5.16,
#   '2015-04': 9.09,
#   '2015-05': 15.34,
#   '2015-06': 18,
#   '2015-07': 22.57,
#   '2015-08': 21.62,
#   '2015-09': 16.68,
#   '2015-10': 10.92,
#   '2015-11': 6.66,
#   '2015-12': 2.7,
#   '2016-01': 1.29,
#   '2016-02': 6.08,
#   '2016-03': 5.95,
#   '2016-04': 11.84,
#   '2016-05': 13.65,
#   '2016-06': 18.74,
#   '2016-07': 20.84,
#   '2016-08': 18.6,
#   '2016-09': 15.7,
#   '2016-10': 9.61,
#   '2016-11': 6.04,
#   '2016-12': 0.45,
#   '2017-01': -5.36,
#   '2017-02': 4.12,
#   '2017-03': 8.26,
#   '2017-04': 9.08,
#   '2017-05': 14.82,
#   '2017-06': 19.86,
#   '2017-07': 21.31,
#   '2017-08': 22.04,
#   '2017-09': 14.79,
#   '2017-10': 10.71,
#   '2017-11': 5.41,
#   '2017-12': 2.12,
#   '2018-01': 3.34,
#   '2018-02': -0.11,
#   '2018-03': 4.26,
#   '2018-04': 14,
#   '2018-05': 16.62,
#   '2018-06': 18.17,
#   '2018-07': 19.89,
#   '2018-08': 20.81,
#   '2018-09': 16.2,
#   '2018-10': 12.61,
#   '2018-11': 7.19,
#   '2018-12': 1.11,
#   '2019-01': -1.07,
#   '2019-02': 3.15,
#   '2019-03': 7.51,
#   '2019-04': 10.53,
#   '2019-05': 11.6,
#   '2019-06': 20.52,
#   '2019-07': 20.38,
#   '2019-08': 21.58,
#   '2019-09': 16.16,
#   '2019-10': 12.57,
#   '2019-11': 9.61,
#   '2019-12': 3.68,
#   '2020-01': 0.98,
#   '2020-02': 5,
#   '2020-03': 6.07,
#   '2020-04': 10.45,
#   '2020-05': 13.59,
#   '2020-06': 17.42,
#   '2020-07': 19.81,
#   '2020-08': 20.98,
#   '1958-10': 21.68,
#   '1958-11': 18.22,
#   '1958-12': 14.94,
#   '1959-01': 12.86,
#   '1959-02': 9.3,
#   '1959-03': 13.06,
#   '1959-04': 16.96,
#   '1959-05': 20.38,
#   '1959-06': 23.59,
#   '1959-07': 25.81,
#   '1959-08': 26.6,
#   '1959-09': 23.9,
#   '1959-10': 19.85,
#   '1959-11': 17.1,
#   '1959-12': 14.71,
#   '1960-01': 12.94,
#   '1960-02': 13.24,
#   '1960-03': 14.3,
#   '1960-04': 17.7,
#   '1960-05': 22.54,
#   '1960-06': 24.95,
#   '1960-07': 27.66,
#   '1960-08': 28.1,
#   '1960-09': 25.21,
#   '1960-10': 23.44,
#   '1960-11': 19.11,
#   '1960-12': 16.25,
#   '1961-01': 12.56,
#   '1961-02': 11.49,
#   '1961-03': 13.37,
#   '1961-04': 17.5,
#   '1961-05': 21.19,
#   '1961-06': 24.98,
#   '1961-07': 27.94,
#   '1961-08': 28.17,
#   '1961-09': 24.06,
#   '1961-10': 20.89,
#   '1961-11': 17.17,
#   '1961-12': 14.44,
#   '1962-01': 13.08,
#   '1962-02': 12.32,
#   '1962-03': 15.48,
#   '1962-04': 16.74,
#   '1962-05': 21.49,
#   '1962-06': 25.18,
#   '1962-07': 27.78,
#   '1962-08': 28.29,
#   '1962-09': 25.84,
#   '1962-10': 21.9,
#   '1962-11': 20,
#   '1962-12': 15.09,
#   '1963-01': 13.74,
#   '1963-02': 14.14,
#   '1963-03': 13.47,
#   '1963-04': 17.27,
#   '1963-05': 19.69,
#   '1963-06': 24.43,
#   '1963-07': 27.7,
#   '1963-08': 28.84,
#   '1963-09': 25.63,
#   '1963-10': 22.05,
#   '1963-11': 17.96,
#   '1963-12': 13.91,
#   '1964-01': 10.14,
#   '1964-02': 11.75,
#   '1964-03': 14.84,
#   '1964-04': 16.7,
#   '1964-05': 19.35,
#   '1964-06': 24.5,
#   '1964-07': 26.71,
#   '1964-08': 27.15,
#   '1964-09': 24.4,
#   '1964-10': 21.99,
#   '1964-11': 17.66,
#   '1964-12': 13.92,
#   '1965-01': 12.21,
#   '1965-02': 12.25,
#   '1965-03': 14.54,
#   '1965-04': 16.48,
#   '1965-05': 20.05,
#   '1965-06': 25.81,
#   '1965-07': 27.79,
#   '1965-08': 27.03,
#   '1965-09': 25.46,
#   '1965-10': 20.36,
#   '1965-11': 16.92,
#   '1965-12': 14.15,
#   '1966-01': 13.29,
#   '1966-02': 13.63,
#   '1966-03': 14.12,
#   '1966-04': 17.51,
#   '1966-05': 20.29,
#   '1966-06': 24.55,
#   '1966-07': 27.11,
#   '1966-08': 27.74,
#   '1966-09': 25.03,
#   '1966-10': 22.96,
#   '1966-11': 19.98,
#   '1966-12': 14.45,
#   '1967-01': 11.57,
#   '1967-02': 10.57,
#   '1967-03': 12.43,
#   '1967-04': 15.98,
#   '1967-05': 19.85,
#   '1967-06': 23.55,
#   '1967-07': 26.93,
#   '1967-08': 27.8,
#   '1967-09': 24.87,
#   '1967-10': 21.63,
#   '1995-03': 14.33,
#   '1995-04': 16.24,
#   '1995-05': 20.76,
#   '1995-06': 25.74,
#   '1995-07': 27.37,
#   '1995-08': 27.73,
#   '1995-09': 25.37,
#   '1995-10': 21.58,
#   '1995-11': 15.38,
#   '1995-12': 13.42,
#   '1996-01': 11.73,
#   '1996-02': 12.92,
#   '1996-03': 13.39,
#   '1996-04': 15.63,
#   '1996-05': 21.73,
#   '1996-06': 25.23,
#   '1996-07': 27.6,
#   '1996-08': 27.8,
#   '1996-09': 24.99,
#   '1996-10': 20.78,
#   '1996-11': 18.74,
#   '1996-12': 15.48,
#   '1997-01': 13.45,
#   '1997-02': 11.68,
#   '1997-03': 12.68,
#   '1997-04': 14.64,
#   '1997-05': 21.46,
#   '1997-06': 25.09,
#   '1997-07': 28.07,
#   '1997-08': 26.18,
#   '1997-09': 24.45,
#   '1997-10': 21.54,
#   '1997-11': 17.92,
#   '1997-12': 14.43,
#   '1998-01': 12.27,
#   '1998-02': 13.16,
#   '1998-03': 13.55,
#   '1998-04': 18.19,
#   '1998-05': 20.71,
#   '1998-06': 25.61,
#   '1998-07': 28.62,
#   '1998-08': 29.63,
#   '1998-09': 26.1,
#   '1998-10': 23.15,
#   '1998-11': 19.17,
#   '1998-12': 14.93,
#   '1999-01': 13.73,
#   '1999-02': 13.52,
#   '1999-03': 14.98,
#   '1999-04': 17.42,
#   '1999-05': 22.45,
#   '1999-06': 25.76,
#   '1999-07': 28.32,
#   '1999-08': 28.52,
#   '1999-09': 26.2,
#   '1999-10': 23.04,
#   '1999-11': 18.42,
#   '1999-12': 15.61,
#   '2000-01': 11.22,
#   '2000-02': 12.11,
#   '2000-03': 13.48,
#   '2000-04': 17.79,
#   '2000-05': 21.12,
#   '2000-06': 26.29,
#   '2000-07': 29.13,
#   '2000-08': 28.14,
#   '2000-09': 25.82,
#   '2000-10': 21.89,
#   '2000-11': 19.04,
#   '2000-12': 14.72,
#   '2001-01': 13.39,
#   '2001-02': 13.64,
#   '2001-03': 17.08,
#   '2001-04': 18.44,
#   '2001-05': 22,
#   '2001-06': 25.7,
#   '2001-07': 28.1,
#   '2001-08': 28.37,
#   '2001-09': 26.22,
#   '2001-10': 22.61,
#   '2001-11': 17.51,
#   '2001-12': 13.98,
#   '2002-01': 11.51,
#   '2002-02': 14.43,
#   '2002-03': 15.8,
#   '2002-04': 17.08,
#   '2002-05': 21.06,
#   '2002-06': 25.76,
#   '2002-07': 28.72,
#   '2002-08': 28.26,
#   '2002-09': 25.76,
#   '2002-10': 22.88,
#   '2002-11': 19.41,
#   '2002-12': 13.43,
#   '2003-01': 14.28,
#   '2003-02': 11.43,
#   '2003-03': 12.99,
#   '2003-04': 16.72,
#   '2003-05': 23.24,
#   '2003-06': 25.7,
#   '2003-07': 28.62,
#   '2003-08': 28.75,
#   '2003-09': 25.58,
#   '2003-10': 22.91,
#   '2003-11': 18.34,
#   '2003-12': 14.4,
#   '2004-01': 12.04,
#   '2004-02': 12.43,
#   '2004-03': 15.19,
#   '2004-04': 17.44,
#   '2004-05': 20.7,
#   '2004-06': 24.93,
#   '2004-07': 28.31,
#   '2004-08': 27.52,
#   '2004-09': 25.74,
#   '2004-10': 23.5,
#   '2004-11': 17.96,
#   '2004-12': 13.6,
#   '2005-01': 13.08,
#   '2005-02': 12.18,
#   '2005-03': 14.96,
#   '2005-04': 17.63,
#   '2005-05': 20.91,
#   '2005-06': 24.34,
#   '2005-07': 27.81,
#   '2005-08': 27.88,
#   '2005-09': 25.74,
#   '2005-10': 21.11,
#   '2005-11': 16.44,
#   '2005-12': 14.52,
#   '2006-01': 11.84,
#   '2006-02': 12.6,
#   '2006-03': 14.32,
#   '2006-04': 17.43,
#   '2006-05': 21.21,
#   '2006-06': 25.29,
#   '2006-07': 27.49,
#   '2006-08': 28.27,
#   '2006-09': 26.04,
#   '2006-10': 21.89,
#   '2006-11': 16.57,
#   '2006-12': 13.45,
#   '2007-01': 12.26,
#   '2007-02': 12.8,
#   '2007-03': 14.59,
#   '2007-04': 16.78,
#   '2007-05': 21.53,
#   '2007-06': 25.75,
#   '2007-07': 28.7,
#   '2007-08': 28.26,
#   '2007-09': 25.89,
#   '2007-10': 23.24,
#   '2007-11': 18.43,
#   '2007-12': 14.1,
#   '2008-01': 11.34,
#   '2008-02': 12.07,
#   '2008-03': 16.54,
#   '2008-04': 18.56,
#   '2008-05': 21.05,
#   '2008-06': 26.2,
#   '2008-07': 28.45,
#   '2008-08': 28.91,
#   '2008-09': 25.83,
#   '2008-10': 22.15,
#   '2008-11': 19.22,
#   '2008-12': 14.68,
#   '2009-01': 13.44,
#   '2009-02': 13.15,
#   '2009-03': 14.04,
#   '2009-04': 17.42,
#   '2009-05': 20.96,
#   '2009-06': 26.38,
#   '2009-07': 28.42,
#   '2009-08': 28.4,
#   '2009-09': 25.44,
#   '2009-10': 23.75,
#   '2009-11': 18.05,
#   '2009-12': 15.45,
#   '2010-01': 14.08,
# ...
#   '1954-01': -3.2,
#   '1954-02': -0.63,
#   '1954-03': 4.93,
#   '1954-04': 7.43,
#   '1954-05': 14.33,
#   '1954-06': 19.88,
#   '1954-07': 23.53,
#   '1954-08': 23.76,
#   '1954-09': 18.96,
#   '1954-10': 13.92,
#   '1954-11': 8.11,
#   '1954-12': 3.31,
#   '1955-01': 1.98,
#   '1955-02': 5.21,
#   '1955-03': 5.19,
#   '1955-04': 8.78,
#   '1955-05': 14.56,
#   '1955-06': 19.62,
#   '1955-07': 21.98,
#   '1955-08': 21.27,
#   '1955-09': 18.65,
#   '1955-10': 15.5,
#   '1955-11': 7.55,
#   '1955-12': 2.44,
#   '1956-01': -0.25,
#   '1956-02': -0.07,
#   '1956-03': 0.5700000000000001,
#   '1956-04': 8.59,
#   '1956-05': 12.25,
#   '1956-06': 18.32,
#   '1956-07': 21.53,
#   '1956-08': 22.91,
#   '1956-09': 16.57,
#   '1956-10': 11.42,
#   '1956-11': 4.8100000000000005,
#   '1956-12': -1.9,
#   '1957-01': -3.41,
#   '1957-02': 1.16,
#   '1957-03': 3.88,
#   '1957-04': 9.56,
#   '1957-05': 13.08,
#   '1957-06': 18.69,
#   '1957-07': 22.27,
#   '1957-08': 23.33,
#   '1957-09': 19.97,
#   '1957-10': 14.02,
#   '1957-11': 7.03,
#   '1957-12': 1.65,
#   '1958-01': 0.22,
#   '1958-02': 2,
#   '1958-03': 4.99,
#   '1958-04': 9.15,
#   '1958-05': 15.08,
#   '1958-06': 18.21,
#   '1958-07': 21.07,
#   '1958-08': 22.06,
#   '1958-09': 17.03,
#   '1958-10': 12.07,
#   '1958-11': 7.11,
#   '1958-12': 2.4,
#   '1959-01': 0.61,
#   '1959-02': -5.26,
#   '1959-03': 2.18,
#   '1959-04': 9.39,
#   '1959-05': 13.89,
#   '1959-06': 17.71,
#   '1959-07': 21.74,
#   '1959-08': 20.97,
#   '1959-09': 15.69,
#   '1959-10': 10.27,
#   '1959-11': 6.12,
#   '1959-12': 3.29,
#   '1960-01': 0.62,
#   '1960-02': 0.7000000000000001,
#   '1960-03': 3.3,
#   '1960-04': 8.54,
#   '1960-05': 15.14,
#   '1960-06': 17.68,
#   '1960-07': 21.38,
#   '1960-08': 20.82,
#   '1960-09': 18.22,
#   '1960-10': 14.98,
#   '1960-11': 8.83,
#   '1960-12': 5.02,
#   '1961-01': -0.78,
#   '1961-02': -0.61,
#   '1961-03': 2.15,
#   '1961-04': 9.94,
#   '1961-05': 14.95,
#   '1961-06': 18.97,
#   '1961-07': 21.66,
#   '1961-08': 22.12,
#   '1961-09': 15.4,
#   '1961-10': 12.32,
#   '1961-11': 6.86,
#   '1961-12': 2.52,
#   '1962-01': 0.4,
#   '1962-02': 0.13,
#   '1962-03': 5.98,
#   '1962-04': 8.66,
#   '1962-05': 15.18,
#   '1962-06': 19.33,
#   '1962-07': 22.78,
#   '1962-08': 23.16,
#   '1962-09': 18.74,
#   '1962-10': 13.09,
#   '1962-11': 10.08,
#   '1962-12': 3.32,
#   '1963-01': 2.24,
#   '1963-02': 3.8200000000000003,
#   '1963-03': 2.66,
#   '1963-04': 8.92,
#   '1963-05': 13.11,
#   '1963-06': 18.52,
#   '1963-07': 22.13,
#   '1963-08': 22.7,
#   '1963-09': 18.8,
#   '1963-10': 13.49,
#   '1963-11': 7.9,
#   '1963-12': 2.02,
#   '1964-01': -4.71,
#   '1964-02': -0.19,
#   '1964-03': 5.38,
#   '1964-04': 8.8,
#   '1964-05': 13.46,
#   '1964-06': 18.94,
#   '1964-07': 22,
#   '1964-08': 21.09,
#   '1964-09': 17.6,
#   '1964-10': 13.57,
#   '1964-11': 6.85,
#   '1964-12': 2.27,
#   '1965-01': 0.02,
#   '1965-02': -0.26,
#   '1965-03': 5.22,
#   '1965-04': 8.17,
#   '1965-05': 13.87,
#   '1965-06': 19.55,
#   '1965-07': 21.95,
#   '1965-08': 22.3,
#   '1965-09': 18.87,
#   '1965-10': 9.81,
#   '1965-11': 6.39,
#   '1965-12': 3.13,
#   '1966-01': 3.12,
#   '1966-02': 4.82,
#   '1966-03': 5.51,
#   '1975-04': 11.37,
#   '1975-05': 13.86,
#   '1975-06': 19.13,
#   '1975-07': 22.85,
#   '1975-08': 21.86,
#   '1975-09': 18.1,
#   '1975-10': 11.75,
#   '1975-11': 5.82,
#   '1975-12': -1.04,
#   '1976-01': -1.3599999999999999,
#   '1976-02': -2.64,
#   '1976-03': 3.14,
#   '1976-04': 8.8,
#   '1976-05': 13.49,
#   '1976-06': 17.86,
#   '1976-07': 20.74,
#   '1976-08': 20.77,
#   '1976-09': 16.91,
#   '1976-10': 12.99,
#   '1976-11': 7.6,
#   '1976-12': 2.1,
#   '1977-01': -1.7000000000000002,
#   '1977-02': 4.6,
#   '1977-03': 4.48,
#   '1977-04': 9.59,
#   '1977-05': 14.54,
#   '1977-06': 18.78,
#   '1977-07': 21.93,
#   '1977-08': 22.51,
#   '1977-09': 18.05,
#   '1977-10': 9.63,
#   '1977-11': 7.82,
#   '1977-12': 0.02,
#   '1978-01': 0.58,
#   '1978-02': 3.99,
#   '1978-03': 5.86,
#   '1978-04': 8.77,
#   '1978-05': 14.65,
#   '1978-06': 18.21,
#   '1978-07': 22.66,
#   '1978-08': 20.7,
#   '1978-09': 17.46,
#   '1978-10': 13.34,
#   '1978-11': 4,
#   '1978-12': 2.66,
#   '1979-01': 0.72,
#   '1979-02': 3.2800000000000002,
#   '1979-03': 5.95,
#   '1979-04': 9.54,
#   '1979-05': 14.62,
#   '1979-06': 18.81,
#   '1979-07': 21.04,
#   '1979-08': 22.64,
#   '1979-09': 19.09,
#   '1979-10': 12.61,
#   '1979-11': 7.84,
#   '1979-12': 1.5,
#   '1980-01': -2.37,
#   '1980-02': 0.11,
#   '1980-03': 3.74,
#   '1980-04': 8.39,
#   '1980-05': 14.24,
#   '1980-06': 19.34,
#   '1980-07': 23.71,
#   '1980-08': 22.06,
#   '1980-09': 17.02,
#   '1980-10': 12.96,
#   '1980-11': 7.36,
#   '1980-12': 2.67,
#   '1981-01': 1.19,
#   '1981-02': 1.88,
#   '1981-03': 6.05,
#   '1981-04': 8.72,
#   '1981-05': 12.25,
#   '1981-06': 19.13,
#   '1981-07': 22.42,
#   '1981-08': 21.8,
#   '1981-09': 19.06,
#   '1981-10': 14.58,
#   '1981-11': 4.46,
#   '1981-12': 4.94,
#   '1982-01': 0.17,
#   '1982-02': -1.9300000000000002,
#   '1982-03': 2.81,
#   '1982-04': 9.97,
#   '1982-05': 14.16,
#   '1982-06': 18.46,
#   '1982-07': 20.25,
#   '1982-08': 21.13,
#   '1982-09': 18.71,
#   '1982-10': 12.23,
#   '1982-11': 4.06,
#   '1982-12': 0.9,
#   '1983-01': -3.84,
#   '1983-02': -0.99,
#   '1983-03': 3.92,
#   '1983-04': 10.15,
#   '1983-05': 14.76,
#   '1983-06': 17.75,
#   '1983-07': 21.63,
#   '1983-08': 20.59,
#   '1983-09': 17.81,
#   '1983-10': 11.3,
#   '1983-11': 7.11,
#   '1983-12': 2.51,
#   '1984-01': 1.73,
#   '1984-02': 2.07,
#   '1984-03': 5.22,
#   '1984-04': 8.18,
#   '1984-05': 14.44,
#   '1984-06': 18.69,
#   '1984-07': 21.6,
#   '1984-08': 19.55,
#   '1984-09': 19.3,
#   '1984-10': 12.87,
#   '1984-11': 6.51,
#   '1984-12': -1.28,
#   '1985-01': 1.63,
#   '1985-02': -2.99,
#   '1985-03': 1.87,
#   '1985-04': 10.63,
#   '1985-05': 16.01,
#   '1985-06': 19.18,
#   '1985-07': 20.66,
#   '1985-08': 23.16,
#   '1985-09': 18,
#   '1985-10': 10.41,
#   '1985-11': 8.62,
#   '1985-12': 1.29,
#   '1986-01': 1.33,
#   '1986-02': 2.56,
#   '1986-03': 5.27,
#   '1986-04': 11.58,
#   '1986-05': 12.16,
#   '1986-06': 18.41,
#   '1986-07': 23.03,
#   '1986-08': 23.67,
#   '1986-09': 19.58,
#   '1986-10': 12.15,
#   '1986-11': 3.52,
#   '1986-12': 0.42,
#   '1987-01': 1.16,
#   '1987-02': 2.95,
#   '1987-03': 0.47000000000000003,
#   '1987-04': 7.73,
#   '1987-05': 14.33,
#   '1987-06': 18.89,
#   '1987-07': 22.73,
#   '1987-08': 21.38,
#   '1987-09': 18.47,
#   '1987-10': 11.16,
#   '1987-11': 5.32,
#   '1987-12': 1.8599999999999999,
#   '1988-01': 0.21,
#   '1988-02': 1.31,
#   '1988-03': 3.75,
#   '1988-04': 9.37,
#   '1988-05': 14.44,
#   '1988-06': 18.45,
#   '1988-07': 22.6,
#   '1988-08': 22.14,
#   '1988-09': 17.9,
#   '1988-10': 11.7,
#   '1988-11': 2.98,
#   '1988-12': 2.09,
#   '1989-01': -3.71,
#   '1989-02': -0.36,
#   '1989-03': 6.78,
#   '1989-04': 13.99,
#   '1989-05': 15.1,
#   '1989-06': 19.08,
#   '1989-07': 22.75,
#   '1989-08': 23.06,
#   '1989-09': 18.14,
#   '1989-10': 11.5,
#   '1989-11': 6.1,
#   '1989-12': 0.67,
#   '1990-01': -2.86,
#   '1990-02': 0.76,
#   '1990-03': 5.4,
#   '1990-04': 9.44,
#   '1990-05': 13.83,
#   '1990-06': 18.69,
#   '1990-07': 22.85,
#   '1990-08': 21.39,
#   '1990-09': 17.67,
#   '1990-10': 12.84,
#   '1990-11': 8.03,
#   '1990-12': 2.9,
#   '1991-01': -0.79,
#   '1991-02': -1.1400000000000001,
#   '1991-03': 5.5600000000000005,
#   '1991-04': 10.14,
#   '1991-05': 13.17,
#   '1991-06': 19.36,
#   '1991-07': 22.59,
#   '1991-08': 22.6,
#   '1991-09': 18.05,
#   '1991-10': 13.37,
#   '1991-11': 6.67,
#   '1991-12': -0.96,
#   '1992-01': -3.84,
#   '1992-02': -3.83,
#   '1992-03': 1.97,
#   '1992-04': 9.09,
#   '1992-05': 13.19,
#   '1992-06': 17.98,
#   '1992-07': 20.34,
#   '1992-08': 22.18,
#   '1992-09': 16.87,
#   '1992-10': 14.22,
#   '1992-11': 4.99,
#   '1992-12': -1.6,
#   '1993-01': -2.85,
#   '1993-02': -1.63,
#   '1993-03': 3.43,
#   '1993-04': 8.92,
#   '1993-05': 13.33,
#   '1993-06': 18.46,
#   '1993-07': 21.85,
#   '1993-08': 22.31,
#   '1993-09': 18.45,
#   '1993-10': 14.05,
#   '1993-11': 3.76,
#   '1993-12': 3.2800000000000002,
#   '1994-01': 2.6,
#   '1994-02': 0.84,
#   '1994-03': 5.19,
#   '1994-04': 12.28,
#   '1994-05': 15.36,
#   '1994-06': 19.07,
#   '1994-07': 22.67,
#   '1994-08': 22.38,
#   '1994-09': 21.09,
#   '1994-10': 14.96,
#   '1994-11': 5.26,
#   '1994-12': -0.76,
#   '1995-01': 1.25,
#   '1995-02': 2.92,
#   '1995-03': 5.49,
#   '1995-04': 8.59,
#   '1995-05': 15.33,
#   '1995-06': 19.97,
#   '1995-07': 21.29,
#   '1995-08': 22.39,
#   '1995-09': 18.49,
#   '1995-10': 11.33,
#   '1995-11': 3.65,
#   '1995-12': 1.04,
#   '1996-01': 0.1,
#   '1996-02': 2.39,
#   '1996-03': 3.41,
#   '1996-04': 7.82,
#   '1996-05': 16.48,
#   '1996-06': 18.87,
#   '1996-07': 23.49,
#   '1996-08': 22.58,
#   '1996-09': 17.38,
#   '1996-10': 11.49,
#   '1996-11': 7.63,
#   '1996-12': 5.24,
#   '1997-01': 1.16,
#   '1997-02': -0.86,
#   '1997-03': 1.56,
#   '1997-04': 6.5600000000000005,
#   '1997-05': 15.71,
#   '1997-06': 19.17,
#   '1997-07': 22.01,
#   '1997-08': 21.18,
#   '1997-09': 16.16,
#   '1997-10': 12.52,
#   '1997-11': 7.12,
#   '1997-12': 2.5,
#   '1998-01': -0.39,
#   '1998-02': 0.8300000000000001,
#   '1998-03': 3.37,
#   '1998-04': 11.47,
#   '1998-05': 14.88,
#   '1998-06': 20.21,
#   '1998-07': 23.67,
#   '1998-08': 24.03,
#   '1998-09': 18.85,
#   '1998-10': 14.2,
#   '1998-11': 9.18,
#   '1998-12': 3.38,
#   '1999-01': 2.1,
#   '1999-02': 2.42,
#   '1999-03': 5.53,
#   '1999-04': 10.75,
#   '1999-05': 15.85,
#   '1999-06': 19.72,
#   '1999-07': 23.34,
#   '1999-08': 23.33,
#   '1999-09': 18.6,
#   '1999-10': 13.71,
#   '1999-11': 6.84,
#   '1999-12': 4.05,
#   '2000-01': -2.69,
#   '2000-02': -0.51,
#   '2000-03': 2.99,
#   '2000-04': 11.58,
#   '2000-05': 14.62,
#   '2000-06': 19.36,
#   '2000-07': 24.9,
#   '2000-08': 22.61,
#   '2000-09': 18.65,
#   '2000-10': 12.14,
#   '2000-11': 7.97,
#   '2000-12': 2.54,
#   '2001-01': 2.09,
#   '2001-02': 2.87,
#   '2001-03': 9.63,
#   '2001-04': 11.3,
#   '2001-05': 14.06,
#   '2001-06': 20.44,
#   '2001-07': 24.35,
#   '2001-08': 23.87,
#   '2001-09': 19.8,
#   '2001-10': 13.07,
#   '2001-11': 5.86,
#   '2001-12': 1.92,
#   '2002-01': -2.77,
#   '2002-02': 3.49,
#   '2002-03': 6.86,
#   '2002-04': 9.08,
#   '2002-05': 14.58,
#   '2002-06': 19.66,
#   '2002-07': 23.54,
#   '2002-08': 22.15,
#   '2002-09': 18.7,
#   '2002-10': 13.81,
#   '2002-11': 8.05,
#   '2002-12': -1.16,
#   '2003-01': 3.11,
#   '2003-02': -1,
#   '2003-03': 1.8599999999999999,
#   '2003-04': 8.85,
#   '2003-05': 16.54,
#   '2003-06': 19.88,
#   '2003-07': 22.75,
#   '2003-08': 23.36,
#   '2003-09': 17.91,
#   '2003-10': 14.2,
#   '2003-11': 6.63,
#   '2003-12': 1.6099999999999999,
#   '2004-01': -0.03,
#   '2004-02': 0.93,
#   '2004-03': 6.05,
#   '2004-04': 9.64,
#   '2004-05': 14.25,
#   '2004-06': 19.28,
#   '2004-07': 22.37,
#   '2004-08': 22.56,
#   '2004-09': 18.86,
#   '2004-10': 14.35,
#   '2004-11': 6.42,
#   '2004-12': 0.44,
#   '2005-01': 0.96,
#   '2005-02': 0.91,
#   '2005-03': 5.07,
#   '2005-04': 10.48,
#   '2005-05': 15.07,
#   '2005-06': 18.71,
#   '2005-07': 23.78,
#   '2005-08': 23.77,
#   '2005-09': 18.34,
#   '2005-10': 11.41,
#   '2005-11': 5.71,
#   '2005-12': 3.11,
#   '2006-01': -1.67,
#   '2006-02': 1.21,
#   '2006-03': 6.11,
#   '2006-04': 10.99,
#   '2006-05': 15.17,
#   '2006-06': 20.98,
#   '2006-07': 22.3,
#   '2006-08': 25.26,
#   '2006-09': 18.54,
#   '2006-10': 13.64,
#   '2006-11': 5.23,
#   '2006-12': 0.33,
#   '2007-01': -0.28,
#   '2007-02': 1.32,
#   '2007-03': 5.52,
#   '2007-04': 7.66,
#   '2007-05': 17.26,
#   '2007-06': 20.87,
#   '2007-07': 23.9,
#   '2007-08': 24.06,
#   '2007-09': 19.62,
#   '2007-10': 14.27,
#   '2007-11': 6.19,
#   '2007-12': 0.71,
#   '2008-01': -3.67,
#   '2008-02': -1.09,
#   '2008-03': 8.41,
#   '2008-04': 12.51,
#   '2008-05': 14.2,
#   '2008-06': 20.17,
#   '2008-07': 23.36,
#   '2008-08': 24.39,
#   '2008-09': 18.98,
#   '2008-10': 13.15,
#   '2008-11': 8.16,
#   '2008-12': 1.19,
#   '2009-01': 0.55,
#   '2009-02': 3.04,
#   '2009-03': 4.5,
#   '2009-04': 9.21,
#   '2009-05': 14.52,
#   '2009-06': 20.2,
#   '2009-07': 22.57,
#   '2009-08': 21.67,
#   '2009-09': 17.41,
#   '2009-10': 15.07,
#   '2009-11': 6.91,
#   '2009-12': 4.86,
#   '2010-01': 2.68,
#   '2010-02': 4.62,
#   '2010-03': 7.38,
#   '2010-04': 10.52,
#   '2010-05': 15.92,
#   '2010-06': 20.36,
#   '2010-07': 24.29,
#   '2010-08': 25.46,
#   '2010-09': 20.83,
#   '2010-10': 12.93,
#   '2010-11': 9.99,
#   '2010-12': 5.26,
#   '2011-01': 0.78,
#   '2011-02': 1.38,
#   '2011-03': 4.87,
#   '2011-04': 8.85,
#   '2011-05': 13.72,
#   '2011-06': 18.96,
#   '2011-07': 23.71,
#   '2011-08': 22.63,
#   '2011-09': 19,
#   '2011-10': 11.32,
#   '2011-11': 2.58,
#   '2011-12': 1.44,
#   '2012-01': -1.08,
#   '2012-02': -1.9500000000000002,
#   '2012-03': 2.26,
#   '2012-04': 11.75,
#   '2012-05': 15.23,
#   '2012-06': 21.09,
#   '2012-07': 24.07,
#   '2012-08': 23.14,
#   '2012-09': 20.04,
#   '2012-10': 14.93,
#   '2012-11': 8.93,
#   '2012-12': 2.9699999999999998,
#   '2013-01': 1.08,
#   '2013-02': 3.93,
#   '2013-03': 6.48,
#   '2013-04': 11.12,
#   '2013-05': 16.64,
#   '2013-06': 20.05,
#   '2013-07': 22.52,
#   '2013-08': 22.93,
#   '2013-09': 17.95,
#   '2013-10': 11.11,
#   '2013-11': 8.38,
#   '2013-12': -1.42,
#   '2014-01': 2.35,
#   '2014-02': 3.6,
#   '2014-03': 7.18,
#   '2014-04': 11.66,
#   '2014-05': 15.48,
#   '2014-06': 19.38,
#   '2014-07': 23.81,
#   '2014-08': 24.44,
#   '2014-09': 18.79,
#   '2014-10': 13.09,
#   '2014-11': 6.63,
#   '2014-12': 5.22,
#   '2015-01': 0.31,
#   '2015-02': 2.63,
#   '2015-03': 5.96,
#   '2015-04': 8.93,
#   '2015-05': 15.65,
#   '2015-06': 19.12,
#   '2015-07': 23.54,
#   '2015-08': 24.03,
#   '2015-09': 21.73,
#   '2015-10': 14.27,
#   '2015-11': 8.19,
#   '2015-12': 0.72,
#   '2016-01': -0.11,
#   '2016-02': 5.62,
#   '2016-03': 7.18,
#   '2016-04': 13.19,
#   '2016-05': 15.06,
#   '2016-06': 20.87,
#   '2016-07': 23.78,
#   '2016-08': 24.64,
#   '2016-09': 18.37,
#   '2016-10': 13.7,
#   '2016-11': 6.13,
#   '2016-12': -1.2,
#   '2017-01': -2.1,
#   '2017-02': 0.8300000000000001,
#   '2017-03': 6.43,
#   '2017-04': 10.14,
#   '2017-05': 14.9,
#   '2017-06': 20.18,
#   '2017-07': 24.44,
#   '2017-08': 24.17,
#   '2017-09': 21.28,
#   '2017-10': 12.53,
#   '2017-11': 6.82,
#   '2017-12': 4.24,
#   '2018-01': 2.26,
#   '2018-02': 5.27,
#   '2018-03': 9.33,
#   '2018-04': 13.03,
#   '2018-05': 16.55,
#   '2018-06': 20.43,
#   '2018-07': 24.06,
#   '2018-08': 23.9,
#   '2018-09': 20.04,
#   '2018-10': 14.3,
#   '2018-11': 7.96,
#   '2018-12': 3.09,
#   '2019-01': 1.06,
#   '2019-02': 3.07,
#   '2019-03': 5.7,
#   '2019-04': 9.33,
#   '2019-05': 16.89,
#   '2019-06': 21.7,
#   '2019-07': 22.68,
#   '2019-08': 23.63,
#   '2019-09': 19.22,
#   '2019-10': 15.52,
#   '2019-11': 8.89,
#   '2019-12': 3.92,
#   '2020-01': 0.36,
#   '2020-02': 2.23,
#   '2020-03': 7.37,
#   '2020-04': 10.22,
#   '2020-05': 15.71,
#   '2020-06': 19.95,
#   '2020-07': 24.34,
#   '2020-08': 23.26,
#   '2020-09': 22.14,
#   '2020-10': 16.48,
#   '2020-11': 7.21,
#   '2020-12': 4.57}}

# %%
# (I wrote this function with the help of ChatGPT. I included the full session in my references.)

def get_monthly_averages(temperature):
    keys = ['ALB', 'BIH', 'CYP', 'DZA', 'EGY', 'ESP', 'GRC', 'HRV', 'ISR', 'ITA', 'LBN', 'LBY', 'MAR', 'MCO', 'MLT', 'MNE', 'PSE', 'REU', 'SVN', 'SYR', 'TUN', 'TUR']
    monthly_averages = []
    for ticker in keys:
        country = temperature[ticker]
        temp_list = list(country.values())
        for month in range(12):
            monthly_sum = sum(temp_list[month::12])  # Sum every 12th element (same month over 70 years)
            count = len(temp_list[month::12])  # Number of years
            monthly_average = monthly_sum / count  # Calculate average
            monthly_averages.append(((ticker, month, monthly_average)))
    return monthly_averages

# %%
# Calculate monthly averages for all countries
monthly_averages = get_monthly_averages(tas)

# %%
MAST_ = pd.DataFrame(monthly_averages)

# %%
MAST_.head()
# Out:
#      0  1          2
# 0  ALB  0   2.774366
# 1  ALB  1   4.123099
# 2  ALB  2   7.022254
# 3  ALB  3  10.857746
# 4  ALB  4  15.331690

# %% [markdown]
# I am going to change the numbers in second column to month names.

# %%
replace_dict = {
    0: 'Jan',
    1: 'Feb',
    2: 'Mar',
    3: 'Apr',
    4: 'May',
    5: 'Jun',
    6: 'Jul',
    7: 'Aug',
    8: 'Sep',
    9: 'Oct',
    10: 'Nov',
    11: 'Dec'
    
}

MAST = MAST_.replace(replace_dict)

# %%
MAST
# Out:
#        0    1          2
# 0    ALB  Jan   2.774366
# 1    ALB  Feb   4.123099
# 2    ALB  Mar   7.022254
# 3    ALB  Apr  10.857746
# 4    ALB  May  15.331690
# ..   ...  ...        ...
# 259  TUR  Aug  22.548732
# 260  TUR  Sep  18.542535
# 261  TUR  Oct  12.944648
# 262  TUR  Nov   6.696620
# 263  TUR  Dec   1.857324
#
# [264 rows x 3 columns]

# %% [markdown]
# ## 2.

# %%
pr
# Out:
# {'ALB': {'1950-01': 97.35,
#   '1950-02': 87.45,
#   '1950-03': 57.06,
#   '1950-04': 108.63,
#   '1950-05': 39.78,
#   '1950-06': 23.41,
#   '1950-07': 3.25,
#   '1950-08': 15.54,
#   '1950-09': 44.81,
#   '1950-10': 128.6,
#   '1950-11': 204.28,
#   '1950-12': 225.59,
#   '1951-01': 82.91,
#   '1951-02': 123.01,
#   '1951-03': 133.66,
#   '1951-04': 100.62,
#   '1951-05': 79.9,
#   '1951-06': 63.97,
#   '1951-07': 25.22,
#   '1951-08': 20.46,
#   '1951-09': 29.73,
#   '1951-10': 175.11,
#   '1951-11': 151.17,
#   '1951-12': 99.89,
#   '1952-01': 245.64,
#   '1952-02': 128.6,
#   '1952-03': 65.73,
#   '1952-04': 50.8,
#   '1952-05': 74.75,
#   '1952-06': 22.73,
#   '1952-07': 31.58,
#   '1952-08': 2.33,
#   '1952-09': 53.76,
#   '1952-10': 153.24,
#   '1952-11': 261.51,
#   '1952-12': 250.15,
#   '1953-01': 101.72,
#   '1953-02': 198.31,
#   '1953-03': 13.32,
#   '1953-04': 98.23,
#   '1953-05': 140.51,
#   '1953-06': 76.83,
#   '1953-07': 12.72,
#   '1953-08': 30.12,
#   '1953-09': 31.82,
#   '1953-10': 71.34,
#   '1953-11': 33.9,
#   '1953-12': 97.84,
#   '1954-01': 169.47,
#   '1954-02': 165.12,
#   '1954-03': 92.21,
#   '1954-04': 91.43,
#   '1954-05': 135.14,
#   '1954-06': 42.95,
#   '1954-07': 12.26,
#   '1954-08': 28.87,
#   '1954-09': 34.65,
#   '1954-10': 112.01,
#   '1954-11': 189.38,
#   '1954-12': 138.38,
#   '1955-01': 165.4,
#   '1955-02': 246.65,
#   '1955-03': 112.82,
#   '1955-04': 84.02,
#   '1955-05': 27.91,
#   '1955-06': 32.17,
#   '1955-07': 64.23,
#   '1955-08': 54.44,
#   '1955-09': 187.85,
#   '1955-10': 247.22,
#   '1955-11': 159.14,
#   '1955-12': 126.22,
#   '1956-01': 159.44,
#   '1956-02': 256.53,
#   '1956-03': 99.81,
#   '1956-04': 132.09,
#   '1956-05': 99.38,
#   '1956-06': 97.7,
#   '1956-07': 14.8,
#   '1956-08': 20.25,
#   '1956-09': 30.5,
#   '1956-10': 109.12,
#   '1956-11': 279.95,
#   '1956-12': 92.22,
#   '1957-01': 90.36,
#   '1957-02': 123.23,
#   '1957-03': 27.52,
#   '1957-04': 78.68,
#   '1957-05': 134.22,
#   '1957-06': 28.99,
#   '1957-07': 33.86,
#   '1957-08': 41.1,
#   '1957-09': 119.95,
#   '1957-10': 183.66,
#   '1957-11': 98.71,
#   '1957-12': 218.44,
#   '1958-01': 147.33,
#   '1958-02': 108.24,
#   '1958-03': 294.86,
#   '1958-04': 187.9,
#   '1958-05': 94.91,
#   '1958-06': 37.58,
#   '1958-07': 30.85,
#   '1958-08': 8.73,
#   '1958-09': 57.96,
#   '1958-10': 100.71,
#   '1958-11': 163.42,
#   '1958-12': 155.27,
#   '1959-01': 254.33,
#   '1959-02': 41.22,
#   '1959-03': 83.81,
#   '1959-04': 130.16,
#   '1959-05': 144.3,
#   '1959-06': 103.19,
#   '1959-07': 61.33,
#   '1959-08': 65.4,
#   '1959-09': 71.66,
#   '1959-10': 73.88,
#   '1959-11': 154.5,
#   '1959-12': 183.42,
#   '1960-01': 210.34,
#   '1960-02': 198.79,
#   '1960-03': 161.05,
#   '1960-04': 160.28,
#   '1960-05': 95.74,
#   '1960-06': 32.46,
#   '1960-07': 30.05,
#   '1960-08': 12.77,
#   '1960-09': 108.28,
#   '1960-10': 220.81,
#   '1960-11': 219.43,
#   '1960-12': 208.54,
#   '1961-01': 83.54,
#   '1961-02': 59.29,
#   '1961-03': 74.38,
#   '1961-04': 92.61,
#   '1961-05': 147.87,
#   '1961-06': 53.6,
#   '1961-07': 34.74,
#   '1961-08': 14.82,
#   '1961-09': 14.37,
#   '1961-10': 79.13,
#   '1998-04': 141,
#   '1998-05': 138.23,
#   '1998-06': 45.41,
#   '1998-07': 35.53,
#   '1998-08': 54.32,
#   '1998-09': 165.59,
#   '1998-10': 165.3,
#   '1998-11': 162.32,
#   '1998-12': 123.78,
#   '1999-01': 88.59,
#   '1999-02': 163.28,
#   '1999-03': 128.62,
#   '1999-04': 139.54,
#   '1999-05': 47.74,
#   '1999-06': 58.59,
#   '1999-07': 56.39,
#   '1999-08': 33.79,
#   '1999-09': 55.97,
#   '1999-10': 94.62,
#   '1999-11': 184.67,
#   '1999-12': 241.15,
#   '2000-01': 61.97,
#   '2000-02': 103.02,
#   '2000-03': 107.23,
#   '2000-04': 123.51,
#   '2000-05': 42.22,
#   '2000-06': 31.4,
#   '2000-07': 47.55,
#   '2000-08': 15.58,
#   '2000-09': 82.11,
#   '2000-10': 74.52,
#   '2000-11': 161.54,
#   '2000-12': 131.81,
#   '2001-01': 129.98,
#   '2001-02': 105.66,
#   '2001-03': 96.68,
#   '2001-04': 164.61,
#   '2001-05': 94.12,
#   '2001-06': 49.4,
#   '2001-07': 35.06,
#   '2001-08': 26.06,
#   '2001-09': 128.05,
#   '2001-10': 28.51,
#   '2001-11': 135.82,
#   '2001-12': 164.32,
#   '2002-01': 37.21,
#   '2002-02': 50.7,
#   '2002-03': 66.83,
#   '2002-04': 142.47,
#   '2002-05': 96.25,
#   '2002-06': 44.78,
#   '2002-07': 83.72,
#   '2002-08': 121.99,
#   '2002-09': 225.98,
#   '2002-10': 129.2,
#   '2002-11': 77.89,
#   '2002-12': 178.99,
#   '2003-01': 227.51,
#   '2003-02': 72.65,
#   '2003-03': 20.41,
#   '2003-04': 86.35,
#   '2003-05': 49.22,
#   '2003-06': 50.77,
#   '2003-07': 18,
#   '2003-08': 26.45,
#   '2003-09': 91.79,
#   '2003-10': 341.81,
#   '2003-11': 91.37,
#   '2003-12': 100.81,
#   '2004-01': 196.88,
#   '2004-02': 167.5,
#   '2004-03': 157.65,
#   '2004-04': 129.4,
#   '2004-05': 143.65,
#   '2004-06': 89.62,
#   '2004-07': 73.44,
#   '2004-08': 31.31,
#   '2004-09': 96.97,
#   '2004-10': 117.2,
#   '2004-11': 150.59,
#   '2004-12': 141.27,
#   '2005-01': 129.73,
#   '2005-02': 188.06,
#   '2005-03': 154.84,
#   '2005-04': 101.08,
#   '2005-05': 63.86,
#   '2005-06': 76.68,
#   '2005-07': 42.53,
#   '2005-08': 65.72,
#   '2005-09': 91.43,
#   '2005-10': 75.5,
#   '2005-11': 177.22,
#   '2005-12': 312.6,
#   '2006-01': 115.89,
#   '2006-02': 148.42,
#   '2006-03': 197.96,
#   '2006-04': 107.71,
#   '2006-05': 51.42,
#   '2006-06': 83.45,
#   '2006-07': 53.43,
#   '2006-08': 89.36,
#   '2006-09': 72.94,
#   '2006-10': 29.8,
#   '2006-11': 70.34,
#   '2006-12': 73.77,
#   '2007-01': 111.19,
#   '2007-02': 96.83,
#   '2007-03': 121.58,
#   '2007-04': 56.22,
#   '2007-05': 93.91,
#   '2007-06': 51.96,
#   '2007-07': 6.19,
#   '2007-08': 22.15,
#   '2007-09': 91.29,
#   '2007-10': 120.8,
#   '2007-11': 213.16,
#   '2007-12': 97.5,
#   '2008-01': 78.72,
#   '2008-02': 35.68,
#   '2008-03': 178.91,
#   '2008-04': 89.4,
#   '2008-05': 51.68,
#   '2008-06': 79.95,
#   '2008-07': 51.75,
#   '2008-08': 11.25,
#   '2008-09': 96.69,
#   '2008-10': 73.66,
#   '2008-11': 131.79,
#   '2008-12': 223.23,
#   '2009-01': 221.32,
#   '2009-02': 104.12,
#   '2009-03': 200.72,
#   '2009-04': 81.26,
#   '2009-05': 63.57,
#   '2009-06': 118.28,
#   '2009-07': 40.72,
#   '2009-08': 30.52,
#   '2009-09': 45.15,
#   '2009-10': 171.19,
#   '2009-11': 169.27,
#   '2009-12': 267.42,
#   '2010-01': 222.62,
#   '2010-02': 257.38,
#   '2010-03': 154.88,
#   '2010-04': 121.97,
#   '2010-05': 115.4,
#   '2010-06': 77.38,
#   '2010-07': 55.93,
#   '2010-08': 17.58,
#   '2010-09': 135.57,
#   '2010-10': 213.62,
#   '2010-11': 297.95,
#   '2010-12': 223.19,
#   '2011-01': 78.78,
#   '2011-02': 64.95,
#   '2011-03': 89.41,
#   '2011-04': 39.37,
#   '2011-05': 120.32,
#   '2011-06': 57.49,
#   '2011-07': 40.93,
#   '2011-08': 13.56,
#   '2011-09': 94.61,
#   '2011-10': 75.96,
#   '2011-11': 21.72,
#   '2011-12': 159.19,
#   '2012-01': 94.83,
#   '2012-02': 162,
#   '2012-03': 36.14,
#   '2012-04': 200.86,
#   '2012-05': 128.62,
#   '2012-06': 16.91,
#   '2012-07': 17.58,
#   '2012-08': 14.22,
#   '2012-09': 82.97,
#   '2012-10': 230.75,
#   '2012-11': 175.63,
#   '2012-12': 204.78,
#   '2013-01': 186.47,
#   '2013-02': 183.88,
#   '2013-03': 262.72,
#   '2013-04': 82.11,
#   '2013-05': 140.9,
#   '2013-06': 52.8,
#   '2013-07': 31.46,
#   '2013-08': 37.33,
#   '2013-09': 110.29,
#   '2013-10': 90.59,
#   '2013-11': 175.49,
#   '2013-12': 42.01,
#   '2014-01': 150.52,
#   '2014-02': 79.89,
#   '2014-03': 82.31,
#   '2014-04': 155.4,
#   '2014-05': 130.31,
#   '2014-06': 81.37,
#   '2014-07': 67.17,
#   '2014-08': 29.46,
#   '2014-09': 167.32,
#   '2014-10': 159.23,
#   '2014-11': 141.38,
#   '2014-12': 148.42,
#   '2015-01': 142.79,
#   '2015-02': 154.85,
#   '2015-03': 149.97,
#   '2015-04': 88.59,
#   '2015-05': 45.4,
#   '2015-06': 65.2,
#   '2015-07': 18.3,
#   '2015-08': 51.98,
#   '2015-09': 133.62,
#   '2015-10': 171.73,
#   '2015-11': 127.2,
#   '2015-12': 1.99,
#   '2016-01': 223.36,
#   '2016-02': 159.75,
#   '2016-03': 154.57,
#   '2016-04': 87.56,
#   '2016-05': 151.44,
#   '2016-06': 83.66,
#   '2016-07': 56.9,
#   '2016-08': 41.69,
#   '2016-09': 148.75,
#   '2016-10': 178.4,
#   '2016-11': 235.26,
#   '2016-12': 7.75,
#   '2017-01': 93.21,
#   '2017-02': 91.55,
#   '2017-03': 69.39,
#   '2017-04': 85.43,
#   '2017-05': 107.15,
#   '2017-06': 34.3,
#   '2017-07': 29.12,
#   '2017-08': 12.18,
#   '2017-09': 104.95,
#   '2017-10': 62.77,
#   '2017-11': 204.31,
#   '2017-12': 264.94,
#   '2018-01': 115.25,
#   '2018-02': 274.73,
#   '2018-03': 315.14,
#   '2018-04': 43.45,
#   '2018-05': 163,
#   '2018-06': 139.59,
#   '2018-07': 68.07,
#   '2018-08': 62.34,
#   '2018-09': 10.15,
#   '2018-10': 45.76,
#   '2018-11': 181.99,
#   '2018-12': 98.98,
#   '2019-01': 176.96,
#   '2019-02': 43.81,
#   '2019-03': 37.41,
#   '2019-04': 117.59,
#   '2019-05': 195.73,
#   '2019-06': 63.92,
#   '2019-07': 65.36,
#   '2019-08': 11.3,
#   '2019-09': 66.99,
#   '2019-10': 41.15,
#   '2019-11': 270.47,
#   '2019-12': 175.57,
#   '2020-01': 48.83,
#   '2020-02': 110.39,
#   '2020-03': 157.89,
#   '2020-04': 92.07,
#   '2020-05': 62.65,
#   '2020-06': 78.24,
#   '2020-07': 23.64,
#   '2020-08': 57.18,
#   '2020-09': 113.53,
#   '2020-10': 185.3,
#   '2020-11': 12.27,
#   '2020-12': 201.66},
#  'BIH': {'1950-01': 78.33,
#   '1950-02': 87.53,
#   '1950-03': 81.82,
#   '1950-04': 85.88,
#   '1950-05': 33.8,
#   '1950-06': 20.94,
#   '1950-07': 23.37,
#   '1950-08': 13.63,
#   '1950-09': 34.87,
#   '1950-10': 135.73,
#   '1950-11': 127.9,
#   '1950-12': 201.89,
#   '1951-01': 79.38,
#   '1951-02': 127.55,
#   '1951-03': 124.78,
#   '1951-04': 109.72,
#   '1951-05': 71.88,
#   '1951-06': 76.52,
#   '1951-07': 90.18,
#   '1951-08': 50.54,
#   '1951-09': 83.27,
#   '1951-10': 67.9,
#   '1951-11': 138.6,
#   '1951-12': 61.26,
#   '1952-01': 132.93,
#   '1952-02': 95.7,
#   '1952-03': 61.96,
#   '1952-04': 49.07,
#   '1952-05': 92.56,
#   '1952-06': 64.38,
#   '1952-07': 31.66,
#   '1952-08': 13.89,
#   '1952-09': 99.64,
#   '1952-10': 153.19,
#   '1952-11': 170.74,
#   '1952-12': 293.06,
#   '1953-01': 73.43,
#   '1953-02': 98.83,
#   '1953-03': 22.35,
#   '1953-04': 78.87,
#   '1953-05': 154.31,
#   '1953-06': 107.65,
#   '1953-07': 49.02,
#   '1953-08': 80.18,
#   '1953-09': 42.65,
#   '1953-10': 45.02,
#   '1953-11': 20.01,
#   '1953-12': 64.18,
#   '1954-01': 93.69,
#   '1954-02': 86.48,
#   '1954-03': 104.02,
#   '1954-04': 135.19,
#   '1954-05': 150.8,
#   '1954-06': 104.9,
#   '1954-07': 45.11,
#   '1954-08': 42.48,
#   '1954-09': 65.13,
#   '1954-10': 102.78,
#   '1954-11': 148.06,
#   '1954-12': 95.62,
#   '1955-01': 96.72,
#   '1955-02': 218.43,
#   '1955-03': 134.47,
#   '1955-04': 65.52,
#   '1955-05': 79.81,
#   '1955-06': 89.63,
#   '1955-07': 118.05,
#   '1955-08': 121.49,
#   '1955-09': 140.71,
#   '1955-10': 199.38,
#   '1955-11': 91.63,
#   '1955-12': 118.06,
#   '1956-01': 75.71,
#   '1956-02': 118.03,
#   '1956-03': 69.2,
#   '1956-04': 91.93,
#   '1956-05': 145.23,
#   '1956-06': 177.59,
#   '1956-07': 63.78,
#   '1956-08': 27.94,
#   '1956-09': 17.82,
#   '1956-10': 58.86,
#   '1956-11': 133.82,
#   '1956-12': 75.05,
#   '1957-01': 75.66,
#   '1957-02': 89.44,
#   '1957-03': 29.25,
#   '1957-04': 100.62,
#   '1957-05': 196.39,
#   '1957-06': 45.81,
#   '1957-07': 62,
#   '1957-08': 91.13,
#   '1957-09': 105.15,
#   '1957-10': 91.28,
#   '1957-11': 83.87,
#   '1957-12': 94.53,
#   '1958-01': 86.42,
#   '1958-02': 118.52,
#   '1958-03': 171.49,
#   '1958-04': 176.11,
#   '1958-05': 53.52,
#   '1958-06': 79.51,
#   '1958-07': 43.22,
#   '1958-08': 39.42,
#   '1958-09': 47.75,
#   '1958-10': 71.28,
#   '1958-11': 111.38,
#   '1958-12': 152.5,
#   '1959-01': 131.96,
#   '1959-02': 28.23,
#   '1959-03': 80.09,
#   '1959-04': 104.92,
#   '1959-05': 123.25,
#   '1959-06': 152.45,
#   '1959-07': 80.08,
#   '1959-08': 153.59,
#   '1959-09': 60.79,
#   '1959-10': 65.34,
#   '1959-11': 103.47,
#   '1959-12': 163.96,
#   '1960-01': 91.37,
#   '1960-02': 113.41,
#   '1960-03': 123.12,
#   '1960-04': 120.29,
#   '1960-05': 65.4,
#   '1960-06': 67.66,
#   '1960-07': 127.24,
#   '1960-08': 55.82,
#   '1960-09': 100.13,
#   '1960-10': 133.74,
#   '1960-11': 149.17,
#   '1960-12': 128.35,
#   '1961-01': 54.18,
#   '1961-02': 60.01,
#   '1961-03': 48.82,
#   '1961-04': 114.87,
#   '1961-05': 159.2,
#   '1961-06': 86.89,
#   '1961-07': 85.63,
#   '1961-08': 23.73,
#   '1961-09': 11.92,
#   '1961-10': 133.32,
#   '1961-11': 157.4,
#   '1961-12': 92.17,
#   '1962-01': 88.4,
#   '1962-02': 95.65,
#   '1962-03': 214.64,
#   '1962-04': 115.21,
#   '1962-05': 57.89,
#   '1962-06': 78.89,
#   '1962-07': 87.11,
#   '1962-08': 12.47,
#   '1962-09': 76.6,
#   '1962-10': 65.23,
#   '1962-11': 200.05,
#   '1962-12': 119.55,
#   '1963-01': 137.86,
#   '1963-02': 138.07,
#   '1963-03': 73.86,
#   '1963-04': 84.88,
#   '1963-05': 127.4,
#   '1963-06': 93.99,
#   '1963-07': 104.18,
#   '1963-08': 103.25,
#   '1963-09': 92.06,
#   '1963-10': 78.98,
#   '1963-11': 95.67,
#   '1963-12': 152.59,
#   '1964-01': 15.68,
#   '1964-02': 82.23,
#   '1964-03': 126.03,
#   '1964-04': 103.3,
#   '1964-05': 104.94,
#   '1964-06': 149.49,
#   '1964-07': 93.65,
#   '1964-08': 91.43,
#   '1964-09': 98.05,
#   '1964-10': 229.4,
#   '1964-11': 116.72,
#   '1964-12': 161.57,
#   '1965-01': 71.26,
#   '1965-02': 95.73,
#   '1965-03': 122.7,
#   '1965-04': 145.69,
#   '1965-05': 157.65,
#   '1965-06': 85.88,
#   '1965-07': 39.28,
#   '1965-08': 61.37,
#   '1965-09': 121.9,
#   '1965-10': 5.28,
#   '1965-11': 179.09,
#   '1965-12': 129.66,
#   '1966-01': 134.51,
#   '1966-02': 89.47,
#   '1966-03': 127.04,
#   '1966-04': 148.9,
#   '1966-05': 98.91,
#   '1966-06': 80.5,
#   '1966-07': 130.26,
#   '1966-08': 84.1,
#   '1966-09': 48.79,
#   '1966-10': 101.57,
#   '1966-11': 152.32,
#   '1966-12': 124.41,
#   '1967-01': 100.44,
#   '1967-02': 52.94,
#   '1967-03': 118.04,
#   '1967-04': 120.32,
#   '1967-05': 108.56,
#   '1967-06': 119.94,
#   '1967-07': 118.56,
#   '1967-08': 36.67,
#   '1967-09': 101.53,
#   '1967-10': 38.43,
#   '1967-11': 96.98,
#   '1967-12': 153.26,
#   '1968-01': 141.93,
#   '1968-02': 81.28,
#   '1968-03': 64.13,
#   '1968-04': 50.34,
#   '1968-05': 116.69,
#   '1968-06': 112.52,
#   '1968-07': 62.56,
#   '1968-08': 119.95,
#   '1968-09': 163.83,
#   '1968-10': 25.52,
#   '1968-11': 218.38,
#   '1968-12': 131.97,
#   '1969-01': 84.1,
#   '1969-02': 215.29,
#   '1969-03': 99.56,
#   '1969-04': 99.92,
#   '1969-05': 82.51,
#   '1969-06': 180.35,
#   '1969-07': 88.11,
#   '1969-08': 145.57,
#   '1969-09': 83.27,
#   '1969-10': 9.04,
#   '1969-11': 157.4,
#   '1969-12': 194.95,
#   '1970-01': 160.26,
#   '1970-02': 135.28,
#   '1970-03': 153.57,
#   '1970-04': 142.08,
#   '1970-05': 122.77,
#   '1970-06': 95.34,
#   '1970-07': 97.63,
#   '1970-08': 99.56,
#   '1970-09': 26.5,
#   '1970-10': 100.96,
#   '1970-11': 101.62,
#   '1970-12': 119.04,
#   '1971-01': 131.02,
#   '1971-02': 82.89,
#   '1971-03': 118.34,
#   '1971-04': 100.13,
#   '1971-05': 100.91,
#   '1971-06': 107.27,
#   '1971-07': 65.74,
#   '1971-08': 76.2,
#   '1971-09': 116.65,
#   '1971-10': 46.16,
#   '1971-11': 155.97,
#   '1971-12': 43.88,
#   '1972-01': 101.85,
#   '1972-02': 112.2,
#   '1972-03': 56.65,
#   '1972-04': 145.37,
#   '1972-05': 128.95,
#   '1972-06': 80.41,
#   '1972-07': 197.52,
#   '1972-08': 169.33,
#   '2000-01': 54.58,
#   '2000-02': 61.54,
#   '2000-03': 92.11,
#   '2000-04': 94.83,
#   '2000-05': 76.34,
#   '2000-06': 32.36,
#   '2000-07': 71.12,
#   '2000-08': 26.57,
#   '2000-09': 86.58,
#   '2000-10': 121.66,
#   '2000-11': 150.97,
#   '2000-12': 100,
#   '2001-01': 140.75,
#   '2001-02': 85.64,
#   '2001-03': 108.34,
#   '2001-04': 142.62,
#   '2001-05': 105.99,
#   '2001-06': 168.79,
#   '2001-07': 81.96,
#   '2001-08': 52.6,
#   '2001-09': 221.32,
#   '2001-10': 22.93,
#   '2001-11': 175.13,
#   '2001-12': 93.7,
#   '2002-01': 47.6,
#   '2002-02': 77.12,
#   '2002-03': 71.59,
#   '2002-04': 158.24,
#   '2002-05': 140.42,
#   '2002-06': 58.89,
#   '2002-07': 106.83,
#   '2002-08': 151.15,
#   '2002-09': 172.56,
#   '2002-10': 136.77,
#   '2002-11': 111.75,
#   '2002-12': 103.93,
#   '2003-01': 137.87,
#   '2003-02': 55.25,
#   '2003-03': 30.59,
#   '2003-04': 73.93,
#   '2003-05': 76.95,
#   '2003-06': 69.28,
#   '2003-07': 55.14,
#   '2003-08': 41.27,
#   '2003-09': 85.02,
#   '2003-10': 197.7,
#   '2003-11': 112.28,
#   '2003-12': 75.33,
#   '2004-01': 120.98,
#   '2004-02': 134.84,
#   '2004-03': 100.14,
#   '2004-04': 187.65,
#   '2004-05': 130.65,
#   '2004-06': 96.23,
#   '2004-07': 92.63,
#   '2004-08': 78.02,
#   '2004-09': 78.26,
#   '2004-10': 83.98,
#   '2004-11': 167.88,
#   '2004-12': 138.19,
#   '2005-01': 69.34,
#   '2005-02': 146.51,
#   '2005-03': 114.12,
#   '2005-04': 102.3,
#   '2005-05': 97.41,
#   '2005-06': 91.02,
#   '2005-07': 129.01,
#   '2005-08': 173.62,
#   '2005-09': 101.91,
#   '2005-10': 48.96,
#   '2005-11': 122.26,
#   '2005-12': 178.74,
#   '2006-01': 73.51,
#   '2006-02': 83.37,
#   '2006-03': 139.58,
#   '2006-04': 135.47,
#   '2006-05': 90.73,
#   '2006-06': 109.85,
#   '2006-07': 77.02,
#   '2006-08': 167.66,
#   '2006-09': 79.88,
#   '2006-10': 46.43,
#   '2006-11': 64.98,
#   '2006-12': 70.08,
#   '2007-01': 82.27,
#   '2007-02': 111.83,
#   '2007-03': 129.83,
#   '2007-04': 31.65,
#   '2007-05': 129.81,
#   '2007-06': 95.29,
#   '2007-07': 49.18,
#   '2007-08': 70.34,
#   '2007-09': 136.18,
#   '2007-10': 151.35,
#   '2007-11': 131.35,
#   '2007-12': 94.44,
#   '2008-01': 67.98,
#   '2008-02': 31.94,
#   '2008-03': 154.28,
#   '2008-04': 124.54,
#   '2008-05': 73.78,
#   '2008-06': 100.51,
#   '2008-07': 118.41,
#   '2008-08': 33.49,
#   '2008-09': 100.61,
#   '2008-10': 88.31,
#   '2008-11': 149.58,
#   '2008-12': 156.43,
#   '2009-01': 145.62,
#   '2009-02': 105.1,
#   '2009-03': 139.13,
#   '2009-04': 94.79,
#   '2009-05': 66.69,
#   '2009-06': 159.86,
#   '2009-07': 61.4,
#   '2009-08': 58.6,
#   '2009-09': 43.48,
#   '2009-10': 158.8,
#   '2009-11': 104.4,
#   '2009-12': 214.94,
#   '2010-01': 168.71,
#   '2010-02': 146.43,
#   '2010-03': 118.02,
#   '2010-04': 119.91,
#   '2010-05': 167.76,
#   '2010-06': 161.53,
#   '2010-07': 63.29,
#   '2010-08': 55.91,
#   '2010-09': 147.14,
#   '2010-10': 104.52,
#   '2010-11': 182.81,
#   '2010-12': 147.12,
#   '2011-01': 55.07,
#   '2011-02': 52.18,
#   '2011-03': 70.94,
#   '2011-04': 56.97,
#   '2011-05': 111.93,
#   '2011-06': 70.18,
#   '2011-07': 98.03,
#   '2011-08': 23.99,
#   '2011-09': 48.07,
#   '2011-10': 71.66,
#   '2011-11': 26.99,
#   '2011-12': 114.45,
#   '2012-01': 85.12,
#   '2012-02': 122.02,
#   '2012-03': 19.19,
#   '2012-04': 141.76,
#   '2012-05': 151.93,
#   '2012-06': 38.47,
#   '2012-07': 45.57,
#   '2012-08': 8.62,
#   '2012-09': 88.78,
#   '2012-10': 133.5,
#   '2012-11': 96.96,
#   '2012-12': 154.59,
#   '2013-01': 153.43,
#   '2013-02': 167.54,
#   '2013-03': 177.85,
#   '2013-04': 73.69,
#   '2013-05': 154.43,
#   '2013-06': 81,
#   '2013-07': 57.25,
#   '2013-08': 52.71,
#   '2013-09': 101,
#   '2013-10': 71.32,
#   '2013-11': 152.33,
#   '2013-12': 32.55,
#   '2014-01': 123.85,
#   '2014-02': 107.85,
#   '2014-03': 85.04,
#   '2014-04': 168.75,
#   '2014-05': 213.11,
#   '2014-06': 136.98,
#   '2014-07': 135.86,
#   '2014-08': 100.92,
#   '2014-09': 210.51,
#   '2014-10': 73.36,
#   '2014-11': 86.13,
#   '2014-12': 106.67,
#   '2015-01': 138.49,
#   '2015-02': 109.92,
#   '2015-03': 122.4,
#   '2015-04': 79.36,
#   '2015-05': 117.81,
#   '2015-06': 69.12,
#   '2015-07': 30.88,
#   '2015-08': 70.25,
#   '2015-09': 86.2,
#   '2015-10': 176.11,
#   '2015-11': 88.38,
#   '2015-12': 6.13,
#   '2016-01': 111.89,
#   '2016-02': 155.42,
#   '2016-03': 130.41,
#   '2016-04': 88.69,
#   '2016-05': 142.73,
#   '2016-06': 112.44,
#   '2016-07': 111.68,
#   '2016-08': 81.55,
#   '2016-09': 99.39,
#   '2016-10': 108.19,
#   '2016-11': 124.4,
#   '2016-12': 14.9,
#   '2017-01': 90.4,
#   '2017-02': 96.76,
#   '2017-03': 94.14,
#   '2017-04': 132.93,
#   '2017-05': 110.64,
#   '2017-06': 56.99,
#   '2017-07': 60.82,
#   '2017-08': 34.09,
#   '2017-09': 112.87,
#   '2017-10': 96.8,
#   '2017-11': 142.37,
#   '2017-12': 155.93,
#   '2018-01': 89.09,
#   '2018-02': 161.37,
#   '2018-03': 200.62,
#   '2018-04': 43.15,
#   '2018-05': 119,
#   '2018-06': 159.21,
#   '2018-07': 133.27,
#   '2018-08': 72.34,
#   '2018-09': 54.07,
#   '2018-10': 80.78,
#   '2018-11': 98.29,
#   '2018-12': 101.84,
#   '2019-01': 120.85,
#   '2019-02': 75.25,
#   '2019-03': 55.53,
#   '2019-04': 147.61,
#   '2019-05': 199.88,
#   '2019-06': 108.73,
#   '2019-07': 80.2,
#   '2019-08': 55.63,
#   '2019-09': 73.94,
#   '2019-10': 37.9,
#   '2019-11': 187.44,
#   '2019-12': 122.29,
#   '2020-01': 28.68,
#   '2020-02': 69.66,
#   '2020-03': 80.71,
#   '2020-04': 39.42,
#   '2020-05': 113.4,
#   '2020-06': 131.63,
#   '2020-07': 65.13,
#   '2020-08': 119.86,
#   '2020-09': 85.74,
#   '2020-10': 147.62,
#   '2020-11': 34.98,
#   '2020-12': 177.84},
#  'CYP': {'1950-01': 68.26,
#   '1950-02': 30.95,
#   '1950-03': 54.18,
#   '1950-04': 32.61,
#   '1950-05': 34.12,
#   '1950-06': 2.59,
#   '1950-07': 0.5700000000000001,
#   '1950-08': 0.44,
#   '1950-09': 5.36,
#   '1950-10': 24.25,
#   '1950-11': 25.1,
#   '1950-12': 50.71,
#   '1951-01': 82.13,
#   '1951-02': 66.12,
#   '1951-03': 24.65,
#   '1951-04': 14.88,
#   '1951-05': 5.71,
#   '1951-06': 11.78,
#   '1951-07': 4.4,
#   '1951-08': 1.47,
#   '1951-09': 9.98,
#   '1951-10': 54.74,
#   '1951-11': 65.08,
#   '1951-12': 128.24,
#   '1952-01': 41.14,
#   '1952-02': 68.81,
#   '1952-03': 63.5,
#   '1952-04': 14.19,
#   '1952-05': 14.12,
#   '1952-06': 0.85,
#   '1952-07': 0.53,
#   '1952-08': 0.42,
#   '1952-09': 0.25,
#   '1952-10': 31.27,
#   '1952-11': 51.08,
#   '1952-12': 120.7,
#   '1953-01': 117.45,
#   '1953-02': 54.9,
#   '1953-03': 68.57,
#   '1953-04': 50.88,
#   '1953-05': 6.25,
#   '1953-06': 1.9100000000000001,
#   '1953-07': 0.56,
#   '1953-08': 0.17,
#   '1953-09': 0.87,
#   '1953-10': 17.01,
#   '1953-11': 54.87,
#   '1953-12': 79.76,
#   '1954-01': 120.15,
#   '1954-02': 84.88,
#   '1954-03': 25.07,
#   '1954-04': 37.81,
#   '1954-05': 10.73,
#   '1954-06': 0.44,
#   '1954-07': 0.09,
#   '1954-08': 1.07,
#   '1954-09': 0.98,
#   '1954-10': 62.55,
#   '1954-11': 99.48,
#   '1954-12': 139.14,
#   '1955-01': 52.08,
#   '1955-02': 34.27,
#   '1955-03': 51.66,
#   '1955-04': 13.22,
#   '1955-05': 17.53,
#   '1955-06': 0.09,
#   '1955-07': 0.31,
#   '1955-08': 2.1,
#   '1955-09': 2.25,
#   '1955-10': 20.04,
#   '1955-11': 67.52,
#   '1955-12': 113.71,
#   '1956-01': 88.18,
#   '1956-02': 72.16,
#   '1956-03': 56.4,
#   '1956-04': 8.17,
#   '1956-05': 16.77,
#   '1956-06': 0.25,
#   '1956-07': 0.09,
#   '1956-08': 0.23,
#   '1956-09': 0.4,
#   '1956-10': 1.17,
#   '1956-11': 7.9,
#   '1956-12': 93.61,
#   '1957-01': 83.3,
#   '1957-02': 24.97,
#   '1957-03': 52.34,
#   '1957-04': 32.21,
#   '1957-05': 21.15,
#   '1957-06': 14.03,
#   '1957-07': 3.06,
#   '1957-08': 0.08,
#   '1957-09': 13.7,
#   '1957-10': 27.02,
#   '1957-11': 53.23,
#   '1957-12': 80.08,
#   '1958-01': 117.5,
#   '1958-02': 14.27,
#   '1958-03': 27.35,
#   '1958-04': 5.71,
#   '1958-05': 18.57,
#   '1958-06': 5.8,
#   '1958-07': 0.1,
#   '1958-08': 0.07,
#   '1958-09': 4.2,
#   '1958-10': 6.08,
#   '1958-11': 13.96,
#   '1958-12': 83.1,
#   '1959-01': 89.32,
#   '1959-02': 35.38,
#   '1959-03': 18.43,
#   '1959-04': 8.04,
#   '1959-05': 8.04,
#   '1959-06': 4.79,
#   '1959-07': 10.87,
#   '1959-08': 4.12,
#   '1959-09': 14.73,
#   '1959-10': 35.75,
#   '1959-11': 24.9,
#   '1959-12': 67.33,
#   '1960-01': 64.38,
#   '1960-02': 24.05,
#   '1960-03': 57,
#   '1960-04': 13.57,
#   '1960-05': 11.39,
#   '1960-06': 4.41,
#   '1960-07': 0.14,
#   '1960-08': 0.08,
#   '1960-09': 2.24,
#   '1960-10': 2.91,
#   '1960-11': 50.61,
#   '1960-12': 28.05,
#   '1961-01': 54.7,
#   '1961-02': 103.03,
#   '1961-03': 19.07,
#   '1961-04': 14.05,
#   '1961-05': 10.74,
#   '1961-06': 0.81,
#   '1961-07': 0.06,
#   '1961-08': 0.08,
#   '1961-09': 5.45,
#   '1961-10': 36.97,
#   '1961-11': 27.45,
#   '1961-12': 136.01,
#   '1962-01': 56.93,
#   '1962-02': 84.75,
#   '1962-03': 7,
#   '1962-04': 35.78,
#   '1962-05': 20.84,
#   '1962-06': 0.04,
#   '1962-07': 0.12,
#   '1962-08': 2.13,
#   '1962-09': 1.87,
#   '1962-10': 36.2,
#   '1962-11': 2.42,
#   '1962-12': 124.03,
#   '1963-01': 77.91,
#   '1963-02': 72.89,
#   '1963-03': 55.85,
#   '1963-04': 17.45,
#   '1963-05': 32.39,
#   '1963-06': 3.09,
#   '1963-07': 1.04,
#   '1963-08': 0.14,
#   '1963-09': 19.89,
#   '1963-10': 32.75,
#   '1963-11': 23.44,
#   '1963-12': 21.06,
#   '1964-01': 30.05,
#   '1964-02': 83.38,
#   '1964-03': 30.57,
#   '1964-04': 10.95,
#   '1964-05': 26.54,
#   '1964-06': 4.96,
#   '1964-07': 0.2,
#   '1964-08': 0.33,
#   '1964-09': 5.8100000000000005,
#   '1964-10': 0.41000000000000003,
#   '1964-11': 55.43,
#   '1964-12': 138.19,
#   '1965-01': 99.37,
#   '1965-02': 74.25,
#   '1965-03': 22.65,
#   '1965-04': 26.22,
#   '1965-05': 21.72,
#   '1965-06': 2.9699999999999998,
#   '1965-07': 0.29,
#   '1965-08': 0.99,
#   '1965-09': 0.78,
#   '1965-10': 70.17,
#   '1965-11': 14.75,
#   '1965-12': 76.68,
#   '1966-01': 101.13,
#   '1966-02': 45.97,
#   '1966-03': 36.32,
#   '1966-04': 8.27,
#   '1966-05': 4.44,
#   '1966-06': 0.28,
#   '1966-07': 0.19,
#   '1966-08': 0.31,
#   '1966-09': 17.8,
#   '1966-10': 17.22,
#   '1966-11': 104.84,
#   '1966-12': 97.12,
#   '1967-01': 48.19,
#   '1967-02': 99.46,
#   '1967-03': 76.42,
#   '1967-04': 26.93,
#   '1967-05': 22.81,
#   '1967-06': 6.14,
#   '1967-07': 1.9,
#   '1967-08': 0.12,
#   '1967-09': 4.78,
#   '1967-10': 46.69,
#   '1967-11': 66.6,
#   '1967-12': 84.02,
#   '1968-01': 120.03,
#   '1968-02': 26.58,
#   '1968-03': 48.48,
#   '1968-04': 19.3,
#   '1968-05': 10.62,
#   '1968-06': 1.28,
#   '1968-07': 0.44,
#   '1968-08': 1.18,
#   '1968-09': 8.98,
#   '1968-10': 52.3,
#   '1968-11': 91.96,
#   '1968-12': 178.83,
#   '1969-01': 157.89,
#   '1969-02': 29.22,
#   '1969-03': 82.39,
#   '1969-04': 23.27,
#   '1969-05': 19.78,
#   '1969-06': 3.5,
#   '1969-07': 0.05,
#   '1969-08': 0.06,
#   '1969-09': 0.99,
#   '1969-10': 45.8,
#   '1969-11': 28.57,
#   '1969-12': 86.08,
#   '1970-01': 75.98,
#   '1970-02': 60.56,
#   '1970-03': 48.36,
#   '1970-04': 9.16,
#   '1970-05': 17.16,
#   '1970-06': 0.31,
#   '1970-07': 1.35,
#   '1970-08': 1.28,
#   '1970-09': 4.39,
#   '1970-10': 23.99,
#   '1970-11': 66.41,
#   '1970-12': 56.92,
#   '1971-01': 62.16,
#   '1971-02': 116.67,
#   '1971-03': 29.4,
#   '1971-04': 77.93,
#   '1971-05': 29.67,
#   '1971-06': 4.24,
#   '1971-07': 1.54,
#   '1971-08': 14.03,
#   '1971-09': 0.37,
#   '1971-10': 11.41,
#   '1971-11': 36.45,
#   '1971-12': 73.11,
#   '1972-01': 90.84,
#   '1972-02': 50.33,
#   '1972-03': 73.41,
#   '1972-04': 56.19,
#   '1972-05': 32.3,
#   '1972-06': 23.74,
#   '1972-07': 6.24,
#   '1972-08': 10.62,
#   '1972-09': 3.52,
#   '1972-10': 54.45,
#   '1972-11': 46.09,
#   '1972-12': 39.59,
#   '1973-01': 32.13,
#   '1973-02': 30.37,
#   '1973-03': 14.78,
#   '1973-04': 21.82,
#   '1973-05': 3.69,
#   '1973-06': 6.66,
#   '1973-07': 0.77,
#   '1973-08': 0.05,
#   '1973-09': 1.08,
#   '1973-10': 32.87,
#   '1973-11': 46.44,
#   '1973-12': 32.34,
#   '1974-01': 99.06,
#   '1974-02': 41.25,
#   '1974-03': 65.37,
#   '1974-04': 14.56,
#   '1974-05': 3.81,
#   '1974-06': 2.6,
#   '1974-07': 0,
#   '1974-08': 1.15,
#   '1974-09': 2.2800000000000002,
#   '1974-10': 22.63,
#   '1974-11': 68.93,
#   '1974-12': 152.64,
#   '1975-01': 135.07,
#   '1975-02': 101.51,
#   '1975-03': 16.07,
#   '1975-04': 27.33,
#   '1975-05': 12.74,
#   '1975-06': 6.21,
#   '1975-07': 0.04,
#   '1975-08': 0.58,
#   '1975-09': 0.42,
#   '1975-10': 3.26,
#   '1975-11': 39.81,
#   '1975-12': 128.06,
#   '1976-01': 61.08,
#   '1976-02': 56.59,
#   '1976-03': 76.86,
#   '1976-04': 26.67,
#   '1976-05': 23.98,
#   '1976-06': 1.19,
#   '1976-07': 1.45,
#   '1976-08': 0.23,
#   '1976-09': 1.6800000000000002,
#   '1976-10': 43.73,
#   '1976-11': 46.95,
#   '1976-12': 73.27,
#   '1977-01': 86.23,
#   '1977-02': 25.11,
#   '1977-03': 58.37,
#   '1977-04': 42.53,
#   '1977-05': 1.7000000000000002,
#   '1977-06': 2.07,
#   '1977-07': 3.75,
#   '1977-08': 0.02,
#   '1977-09': 5.02,
#   '1977-10': 9.43,
#   '1977-11': 11.87,
#   '1977-12': 150.39,
#   '1978-01': 121.86,
#   '1978-02': 66.48,
#   '1978-03': 62.09,
#   '1978-04': 20.42,
#   '1978-05': 0.5,
#   '1978-06': 0.29,
#   '1978-07': 0.06,
#   '1978-08': 0.02,
#   '1978-09': 1.9300000000000002,
#   '1978-10': 33.32,
#   '1978-11': 18.92,
#   '1978-12': 7.01,
#   '1979-01': 69.62,
#   '1979-02': 51.28,
#   '1979-03': 32.95,
#   '1979-04': 11.85,
#   '1979-05': 12.15,
#   '1979-06': 15.16,
#   '1979-07': 0.38,
#   '1979-08': 0.89,
#   '1979-09': 0.76,
#   '1979-10': 37.62,
#   '1979-11': 53.22,
#   '1979-12': 129.01,
#   '1980-01': 55.89,
#   '1980-02': 102.07,
#   '1980-03': 47.86,
#   '1980-04': 18.88,
#   '1980-05': 8.44,
#   '1980-06': 1.13,
#   '1980-07': 0.16,
#   '1980-08': 2.12,
#   '1980-09': 1.33,
#   '1980-10': 26.33,
#   '1980-11': 15.6,
#   '1980-12': 46.69,
#   '1981-01': 178.78,
#   '1981-02': 98.23,
#   '1981-03': 35.51,
#   '1981-04': 10.61,
#   '1981-05': 12.3,
#   '1981-06': 3.41,
#   '1981-07': 1.09,
#   '1981-08': 0.07,
#   '1981-09': 1,
#   '1981-10': 6.86,
#   '1981-11': 79.01,
#   '1981-12': 61.68,
#   '1982-01': 56.57,
#   '1982-02': 59.63,
#   '1982-03': 63.47,
#   '1982-04': 20.56,
#   '1982-05': 5.41,
#   '1982-06': 21.9,
#   '1982-07': 0.54,
#   '1982-08': 0.84,
#   '1982-09': 2.99,
#   '1982-10': 23.68,
#   '1982-11': 25.81,
#   '1982-12': 44.77,
#   '1983-01': 49.78,
#   '1983-02': 68.54,
#   '1983-03': 62.82,
#   '1983-04': 26.29,
#   '1983-05': 17.96,
#   '1983-06': 6.23,
#   '1983-07': 0.9,
#   '1983-08': 0.87,
#   '1983-09': 1.48,
#   '1983-10': 21.11,
#   '1983-11': 54.53,
#   '1983-12': 52.83,
#   '1984-01': 66.28,
#   '1984-02': 47.47,
#   '1984-03': 39.29,
#   '1984-04': 40.1,
#   '1984-05': 0.62,
#   '1984-06': 0.39,
#   '1984-07': 2.09,
#   '1984-08': 0.37,
#   '1984-09': 0.29,
#   '1984-10': 2.91,
#   '1984-11': 135.52,
#   '1984-12': 80.4,
#   '1985-01': 116.48,
#   '1985-02': 60.16,
#   '1985-03': 34.5,
#   '1985-04': 18.29,
#   '1985-05': 6.12,
#   '1985-06': 0.48,
#   '1985-07': 0.25,
#   '1985-08': 0.42,
#   '1985-09': 3.5700000000000003,
#   '1985-10': 51.06,
#   '1985-11': 38.31,
#   '1985-12': 75.89,
#   '1986-01': 69.05,
#   '1986-02': 55.22,
#   '1986-03': 18.65,
#   '1986-04': 10.64,
#   '1986-05': 33.77,
#   '1986-06': 3.87,
#   '1986-07': 0.24,
#   '1986-08': 0.33,
#   '1986-09': 6.34,
#   '1986-10': 43.37,
#   '1986-11': 29.84,
#   '1986-12': 70.65,
#   '1987-01': 50.03,
#   '1987-02': 31.99,
#   '1987-03': 114,
#   '1987-04': 16.16,
#   '1987-05': 8.99,
#   '1987-06': 1.92,
#   '1987-07': 0.52,
#   '1987-08': 0.29,
#   '1987-09': 0.92,
#   '1987-10': 46.68,
#   '1987-11': 29.39,
#   '1987-12': 90.29,
#   '1988-01': 55.24,
#   '1988-02': 82.1,
#   '1988-03': 78.87,
#   '1988-04': 22.21,
#   '1988-05': 8.92,
#   '1988-06': 2.69,
#   '1988-07': 3.39,
#   '1988-08': 0.86,
#   '1988-09': 3.05,
#   '1988-10': 51.93,
#   '1988-11': 68.52,
#   '1988-12': 87.85,
#   '1989-01': 80.75,
#   '1989-02': 16.75,
#   '1989-03': 37.37,
#   '1989-04': 0.13,
#   '1989-05': 3.93,
#   '1989-06': 2.15,
#   '1989-07': 0.15,
#   '1989-08': 0.19,
#   '1989-09': 1.16,
#   '1989-10': 40.25,
#   '1989-11': 59.64,
#   '1989-12': 51.08,
#   '1990-01': 34.03,
#   '1990-02': 101.84,
#   '1990-03': 20.19,
#   '1990-04': 5.26,
#   '1990-05': 5.19,
#   '1990-06': 1.45,
#   '1990-07': 0.28,
#   '1990-08': 2.44,
#   '1990-09': 1.42,
#   '1990-10': 13.34,
#   '1990-11': 11.16,
#   '1990-12': 20.93,
#   '1991-01': 72.93,
#   '1991-02': 58.4,
#   '1991-03': 56.23,
#   '1991-04': 9.93,
#   '1991-05': 9.18,
#   '1991-06': 0.14,
#   '1991-07': 0.19,
#   '1991-08': 0.68,
#   '1991-09': 0.65,
#   '1991-10': 25.13,
#   '1991-11': 90.52,
#   '1991-12': 230.6,
#   '1992-01': 34.74,
#   '1992-02': 86.67,
#   '1992-03': 30.65,
#   '1992-04': 8.09,
#   '1992-05': 25.58,
#   '1992-06': 7.39,
#   '1992-07': 6.57,
#   '1992-08': 4.04,
#   '1992-09': 1.06,
#   '1992-10': 4.18,
#   '1992-11': 72.75,
#   '1992-12': 95,
#   '1993-01': 59.24,
#   '1993-02': 56.15,
#   '1993-03': 47.34,
#   '1993-04': 10.53,
#   '1993-05': 35.35,
#   '1993-06': 4.36,
#   '1993-07': 0.52,
#   '1993-08': 0.23,
#   '1993-09': 0.15,
#   '1993-10': 2.26,
#   '1993-11': 35.58,
#   '1993-12': 18.46,
#   '1994-01': 95.73,
#   '1994-02': 70.6,
#   '1994-03': 53.99,
#   '1994-04': 14.31,
#   '1994-05': 7.91,
#   '1994-06': 0.47000000000000003,
#   '1994-07': 2.19,
#   '1994-08': 1.43,
#   '1994-09': 7.12,
#   '1994-10': 46.49,
#   '1994-11': 129.65,
#   '1994-12': 54.55,
#   '1995-01': 47.29,
#   '1995-02': 29.51,
#   '1995-03': 23.74,
#   '1995-04': 24.52,
#   '1995-05': 11.08,
#   '1995-06': 0.62,
#   '1995-07': 3.69,
#   '1995-08': 0.66,
#   '1995-09': 0.66,
#   '1995-10': 12.2,
#   '1995-11': 58.66,
#   '1995-12': 12.69,
#   '1996-01': 97.56,
#   '1996-02': 47.22,
#   '1996-03': 65.55,
#   '1996-04': 38.51,
#   '1996-05': 5.29,
#   '1996-06': 1.74,
#   '1996-07': 0.06,
#   '1996-08': 0.9400000000000001,
#   '1996-09': 3.86,
#   '1996-10': 56.77,
#   '1996-11': 18.9,
#   '1996-12': 79.03,
#   '1997-01': 18.87,
#   '1997-02': 60.94,
#   '1997-03': 30.41,
#   '1997-04': 45.5,
#   '1997-05': 6.89,
#   '1997-06': 4.38,
#   '1997-07': 0.11,
#   '1997-08': 1.79,
#   '1997-09': 16.84,
#   '1997-10': 49.14,
#   '1997-11': 55.82,
#   '1997-12': 68.83,
#   '1998-01': 51.78,
#   '1998-02': 15.1,
#   '1998-03': 53.14,
#   '1998-04': 22.09,
#   '1998-05': 20.22,
#   '1998-06': 1.73,
#   '1998-07': 0.8200000000000001,
#   '1998-08': 0.1,
#   '1998-09': 2.06,
#   '1998-10': 10.57,
#   '1998-11': 46.06,
#   '1998-12': 126.83,
#   '1999-01': 51.89,
#   '1999-02': 46.09,
#   '1999-03': 32.38,
#   '1999-04': 37.02,
#   '1999-05': 0.78,
#   '1999-06': 7.67,
#   '1999-07': 1.54,
#   '1999-08': 4.5600000000000005,
#   '1999-09': 2.09,
#   '1999-10': 17.32,
#   '1999-11': 18.85,
#   '1999-12': 24.73,
#   '2000-01': 69.1,
#   '2000-02': 49.89,
#   '2000-03': 31.03,
#   '2000-04': 52.93,
#   '2000-05': 15.27,
#   '2000-06': 0.59,
#   '2000-07': 0.39,
#   '2000-08': 1.16,
#   '2000-09': 15.27,
#   '2000-10': 34.56,
#   '2000-11': 71.93,
#   '2000-12': 51.18,
#   '2001-01': 54.46,
#   '2001-02': 68.51,
#   '2001-03': 6.82,
#   '2001-04': 17.8,
#   '2001-05': 13.66,
#   '2001-06': 0.04,
#   '2001-07': 0.08,
#   '2001-08': 4.08,
#   '2001-09': 2.07,
#   '2001-10': 30.2,
#   '2001-11': 68.17,
#   '2001-12': 175.13,
#   '2002-01': 78.19,
#   '2002-02': 46.42,
#   '2002-03': 37.93,
#   '2002-04': 28.83,
#   '2002-05': 9.2,
#   '2002-06': 0.9400000000000001,
#   '2002-07': 3.88,
#   '2002-08': 0.6900000000000001,
#   '2002-09': 5.25,
#   '2002-10': 10.26,
#   '2002-11': 13.31,
#   '2002-12': 119.55,
#   '2003-01': 65.45,
#   '2003-02': 101.15,
#   '2003-03': 72.31,
#   '2003-04': 24.14,
#   '2003-05': 6.91,
#   '2003-06': 6.89,
#   '2003-07': 0.05,
#   '2003-08': 0.06,
#   '2003-09': 1.9500000000000002,
#   '2003-10': 9.52,
#   '2003-11': 27.5,
#   '2003-12': 105.09,
#   '2004-01': 190.7,
#   '2004-02': 71.11,
#   '2004-03': 2.09,
#   '2004-04': 14.44,
#   '2004-05': 5.53,
#   '2004-06': 2.18,
#   '2004-07': 0.05,
#   '2004-08': 0.62,
#   '2004-09': 0.48,
#   '2004-10': 14.08,
#   '2004-11': 75.62,
#   '2004-12': 63.99,
#   '2005-01': 110.32,
#   '2005-02': 37.58,
#   '2005-03': 15.37,
#   '2005-04': 20.66,
#   '2005-05': 9.19,
#   '2005-06': 10.05,
#   '2005-07': 0.62,
#   '2005-08': 2.08,
#   '2005-09': 4.63,
# ...
#   '1954-05': 79.9,
#   '1954-06': 46.1,
#   '1954-07': 21.45,
#   '1954-08': 16.27,
#   '1954-09': 24.17,
#   '1954-10': 29.5,
#   '1954-11': 54.36,
#   '1954-12': 108.72,
#   '1955-01': 46.29,
#   '1955-02': 60.13,
#   '1955-03': 64.96,
#   '1955-04': 77.44,
#   '1955-05': 41.62,
#   '1955-06': 16.19,
#   '1955-07': 25.51,
#   '1955-08': 21.54,
#   '1955-09': 25.89,
#   '1955-10': 37.54,
#   '1955-11': 110.12,
#   '1955-12': 86.72,
#   '1956-01': 75.68,
#   '1956-02': 137.74,
#   '1956-03': 85.92,
#   '1956-04': 45.99,
#   '1956-05': 59.85,
#   '1956-06': 26.83,
#   '1956-07': 7.76,
#   '1956-08': 9.03,
#   '1956-09': 16.83,
#   '1956-10': 18.25,
#   '1956-11': 56.37,
#   '1956-12': 74.09,
#   '1957-01': 56.15,
#   '1957-02': 54.62,
#   '1957-03': 76.61,
#   '1957-04': 61.86,
#   '1957-05': 108.03,
#   '1957-06': 48.65,
#   '1957-07': 13.49,
#   '1957-08': 6.48,
#   '1957-09': 26.82,
#   '1957-10': 23.38,
#   '1957-11': 55.44,
#   '1957-12': 86.61,
#   '1958-01': 121.98,
#   '1958-02': 42.31,
#   '1958-03': 127.57,
#   '1958-04': 74.87,
#   '1958-05': 55.41,
#   '1958-06': 56.32,
#   '1958-07': 19.75,
#   '1958-08': 12.7,
#   '1958-09': 23.79,
#   '1958-10': 29.28,
#   '1958-11': 24.27,
#   '1958-12': 77.24,
#   '1959-01': 125.54,
#   '1959-02': 60.45,
#   '1959-03': 50.6,
#   '1959-04': 61.19,
#   '1959-05': 68.85,
#   '1959-06': 46.34,
#   '1959-07': 34.81,
#   '1959-08': 30.32,
#   '1959-09': 34.71,
#   '1959-10': 60.28,
#   '1959-11': 59.54,
#   '1959-12': 75.26,
#   '1960-01': 92.19,
#   '1960-02': 65.21,
#   '1960-03': 87.69,
#   '1960-04': 91.32,
#   '1960-05': 53.94,
#   '1960-06': 52.51,
#   '1960-07': 28.68,
#   '1960-08': 21.68,
#   '1960-09': 17.2,
#   '1960-10': 20.37,
#   '1960-11': 47.41,
#   '1960-12': 68.26,
#   '1961-01': 72.89,
#   '1961-02': 83.47,
#   '1961-03': 67,
#   '1961-04': 50.55,
#   '1961-05': 55.18,
#   '1961-06': 42.79,
#   '1961-07': 11,
#   '1961-08': 8.99,
#   '1961-09': 26.8,
#   '1961-10': 20.59,
#   '1961-11': 59.49,
#   '1961-12': 105.09,
#   '1962-01': 50.51,
#   '1962-02': 102.89,
#   '1962-03': 65.7,
#   '1962-04': 65.72,
#   '1962-05': 51.7,
#   '1962-06': 19.13,
#   '1962-07': 19.69,
#   '1962-08': 10.96,
#   '1962-09': 21.25,
#   '1962-10': 38.67,
#   '1962-11': 28.29,
#   '1962-12': 154.5,
#   '1963-01': 141.92,
#   '1963-02': 107.33,
#   '1963-03': 90.46,
#   '1963-04': 102.03,
#   '1963-05': 129.83,
#   '1963-06': 50.37,
#   '1963-07': 34.59,
#   '1963-08': 15.52,
#   '1963-09': 38.05,
#   '1963-10': 63.26,
#   '1963-11': 35.38,
#   '1963-12': 80.07,
#   '1964-01': 33.44,
#   '1964-02': 83.05,
#   '1964-03': 105.9,
#   '1964-04': 53.45,
#   '1964-05': 68.37,
#   '1964-06': 66.68,
#   '1964-07': 14.69,
#   '1964-08': 16.44,
#   '1964-09': 34.38,
#   '1964-10': 10.65,
#   '1964-11': 88.73,
#   '1964-12': 76.04,
#   '1965-01': 63.44,
#   '1965-02': 138.71,
#   '1965-03': 76.79,
#   '1965-04': 113.81,
#   '1965-05': 76.33,
#   '1965-06': 35.48,
#   '1965-07': 25.62,
#   '1965-08': 18.74,
#   '1965-09': 13.87,
#   '1965-10': 65.56,
#   '1965-11': 80.22,
#   '1965-12': 107.18,
#   '1966-01': 163.35,
#   '1966-02': 36.41,
#   '1966-03': 88.05,
#   '1966-04': 79.34,
#   '1966-05': 55.67,
#   '1966-06': 26.58,
#   '1966-07': 19.89,
#   '1966-08': 25.92,
#   '1966-09': 33.22,
#   '1966-10': 22.1,
#   '1966-11': 56.49,
#   '1966-12': 137.06,
#   '1967-01': 108.36,
#   '1967-02': 65.21,
#   '1967-03': 100.95,
#   '1967-04': 91.67,
#   '1967-05': 89.43,
#   '1967-06': 44.8,
#   '1967-07': 21.7,
#   '1967-08': 20.99,
#   '1967-09': 25.12,
#   '1967-10': 57.22,
#   '1967-11': 85.15,
#   '1967-12': 111.59,
#   '1968-01': 169.59,
#   '1977-04': 94.48,
#   '1977-05': 57.48,
#   '1977-06': 35.41,
#   '1977-07': 17.93,
#   '1977-08': 13.05,
#   '1977-09': 25.76,
#   '1977-10': 42.01,
#   '1977-11': 39.77,
#   '1977-12': 102.61,
#   '1978-01': 120.1,
#   '1978-02': 100.61,
#   '1978-03': 93.45,
#   '1978-04': 92.15,
#   '1978-05': 38.35,
#   '1978-06': 29.68,
#   '1978-07': 8.76,
#   '1978-08': 18.67,
#   '1978-09': 42.4,
#   '1978-10': 67.83,
#   '1978-11': 27.6,
#   '1978-12': 10.51,
#   '1979-01': 119.2,
#   '1979-02': 69.55,
#   '1979-03': 52.6,
#   '1979-04': 67.15,
#   '1979-05': 84.55,
#   '1979-06': 54.26,
#   '1979-07': 28.62,
#   '1979-08': 23.11,
#   '1979-09': 17.95,
#   '1979-10': 76.01,
#   '1979-11': 99.72,
#   '1979-12': 86.35,
#   '1980-01': 100.39,
#   '1980-02': 59.32,
#   '1980-03': 111.74,
#   '1980-04': 104.13,
#   '1980-05': 83.86,
#   '1980-06': 27.15,
#   '1980-07': 11.93,
#   '1980-08': 15.95,
#   '1980-09': 25.82,
#   '1980-10': 36.92,
#   '1980-11': 73.47,
#   '1980-12': 98.54,
#   '1981-01': 146.09,
#   '1981-02': 88.19,
#   '1981-03': 79.68,
#   '1981-04': 56.19,
#   '1981-05': 85.12,
#   '1981-06': 47.35,
#   '1981-07': 24.37,
#   '1981-08': 19.84,
#   '1981-09': 19.94,
#   '1981-10': 39.25,
#   '1981-11': 95.9,
#   '1981-12': 128.44,
#   '1982-01': 67.58,
#   '1982-02': 59.11,
#   '1982-03': 68.02,
#   '1982-04': 98.54,
#   '1982-05': 80.14,
#   '1982-06': 39.17,
#   '1982-07': 39.66,
#   '1982-08': 24.16,
#   '1982-09': 20.72,
#   '1982-10': 43.07,
#   '1982-11': 38.49,
#   '1982-12': 66.53,
#   '1983-01': 73.43,
#   '1983-02': 90.08,
#   '1983-03': 67.18,
#   '1983-04': 73.01,
#   '1983-05': 78.03,
#   '1983-06': 50.28,
#   '1983-07': 38.57,
#   '1983-08': 22.65,
#   '1983-09': 23.8,
#   '1983-10': 61.54,
#   '1983-11': 134.31,
#   '1983-12': 48.85,
#   '1984-01': 74.61,
#   '1984-02': 58.51,
#   '1984-03': 92.78,
#   '1984-04': 117.26,
#   '1984-05': 54.44,
#   '1984-06': 27.1,
#   '1984-07': 32.81,
#   '1984-08': 24.54,
#   '1984-09': 6.7,
#   '1984-10': 24.01,
#   '1984-11': 70.69,
#   '1984-12': 44.52,
#   '1985-01': 98.86,
#   '1985-02': 113.39,
#   '1985-03': 57.44,
#   '1985-04': 72.06,
#   '1985-05': 63.68,
#   '1985-06': 29.42,
#   '1985-07': 13.17,
#   '1985-08': 12.86,
#   '1985-09': 16.3,
#   '1985-10': 81.44,
#   '1985-11': 76.37,
#   '1985-12': 60.56,
#   '1986-01': 99.65,
#   '1986-02': 92.98,
#   '1986-03': 26.96,
#   '1986-04': 51.18,
#   '1995-06': 54.03,
#   '1995-07': 44.22,
#   '1995-08': 20.68,
#   '1995-09': 35.29,
#   '1995-10': 51.65,
#   '1995-11': 115.04,
#   '1995-12': 39.96,
#   '1996-01': 71.4,
#   '1996-02': 77.9,
#   '1996-03': 125.48,
#   '1996-04': 97.68,
#   '1996-05': 55.89,
#   '1996-06': 25.72,
#   '1996-07': 18.98,
#   '1996-08': 23.5,
#   '1996-09': 57.2,
#   '1996-10': 81.17,
#   '1996-11': 22.84,
#   '1996-12': 115.84,
#   '1997-01': 45.17,
#   '1997-02': 63.75,
#   '1997-03': 74.91,
#   '1997-04': 107.28,
#   '1997-05': 58.56,
#   '1997-06': 56.69,
#   '1997-07': 23.36,
#   '1997-08': 37.07,
#   '1997-09': 33.22,
#   '1997-10': 96.62,
#   '1997-11': 43.6,
#   '1997-12': 96.45,
#   '1998-01': 60.95,
#   '1998-02': 54.52,
#   '1998-03': 112.88,
#   '1998-04': 74.1,
#   '1998-05': 113.7,
#   '1998-06': 38.26,
#   '1998-07': 20.87,
#   '1998-08': 8.16,
#   '1998-09': 30.12,
#   '1998-10': 40.53,
#   '1998-11': 70.01,
#   '1998-12': 100.36,
#   '1999-01': 54.25,
#   '1999-02': 103.01,
#   '1999-03': 85.56,
#   '1999-04': 62.89,
#   '1999-05': 40.04,
#   '1999-06': 58.53,
#   '1999-07': 29.38,
#   '1999-08': 33.91,
#   '1999-09': 30.51,
#   '1999-10': 43.84,
#   '1999-11': 43.99,
#   '1999-12': 47.81,
#   '2000-01': 104.16,
#   '2000-02': 74.33,
#   '2000-03': 68.31,
#   '2000-04': 91.69,
#   '2000-05': 67.28,
#   '2000-06': 31.07,
#   '2000-07': 6.65,
#   '2000-08': 28.54,
#   '2000-09': 28.14,
#   '2000-10': 53.45,
#   '2000-11': 26.08,
#   '2000-12': 60.15,
#   '2001-01': 25.73,
#   '2001-02': 69.65,
#   '2001-03': 59.41,
#   '2001-04': 81.78,
#   '2001-05': 102.04,
#   '2001-06': 16.39,
#   '2001-07': 19.05,
#   '2001-08': 23.34,
#   '2001-09': 21.96,
#   '2001-10': 25.18,
#   '2001-11': 104.11,
#   '2001-12': 174.15,
#   '2002-01': 77.04,
#   '2002-02': 40.84,
#   '2002-03': 82.18,
#   '2002-04': 111.54,
#   '2002-05': 50.12,
#   '2002-06': 36.47,
#   '2002-07': 37.81,
#   '2002-08': 30.65,
#   '2002-09': 43.51,
#   '2002-10': 40.28,
#   '2002-11': 48.95,
#   '2002-12': 73.58,
#   '2003-01': 68.59,
#   '2003-02': 116.36,
#   '2003-03': 83.7,
#   '2003-04': 98.41,
#   '2003-05': 52.63,
#   '2003-06': 18.2,
#   '2003-07': 17.78,
#   '2003-08': 11.07,
#   '2003-09': 32.95,
#   '2003-10': 69.32,
#   '2003-11': 47.94,
#   '2003-12': 89.24,
#   '2004-01': 136.98,
#   '2004-02': 78.17,
#   '2004-03': 47.28,
#   '2004-04': 69.88,
#   '2004-05': 69.93,
#   '2004-06': 39.81,
#   '2004-07': 15.16,
#   '2004-08': 24.81,
#   '2004-09': 10,
#   '2004-10': 25.97,
#   '2004-11': 99.95,
#   '2004-12': 40.92,
#   '2005-01': 79.86,
#   '2005-02': 79.7,
#   '2005-03': 97.67,
#   '2005-04': 70.01,
#   '2005-05': 68.49,
#   '2005-06': 40.51,
#   '2005-07': 25.11,
#   '2005-08': 22.11,
#   '2005-09': 32.58,
#   '2005-10': 63.27,
#   '2005-11': 79.48,
#   '2005-12': 61.67,
#   '2006-01': 79.28,
#   '2006-02': 92.6,
#   '2006-03': 85.95,
#   '2006-04': 80.08,
#   '2006-05': 54.71,
#   '2006-06': 31.43,
#   '2006-07': 23.45,
#   '2006-08': 10.77,
#   '2006-09': 42.39,
#   '2006-10': 96.14,
#   '2006-11': 61.39,
#   '2006-12': 23.62,
#   '2007-01': 58.63,
#   '2007-02': 57.23,
#   '2007-03': 76.62,
#   '2007-04': 74.06,
#   '2007-05': 53.68,
#   '2007-06': 35.7,
#   '2007-07': 16.37,
#   '2007-08': 24.88,
#   '2007-09': 13.95,
#   '2007-10': 50.44,
#   '2007-11': 97.87,
#   '2007-12': 84.75,
#   '2008-01': 54.27,
#   '2008-02': 48.87,
#   '2008-03': 62.3,
#   '2008-04': 49.48,
#   '2008-05': 53.45,
#   '2008-06': 27.39,
#   '2008-07': 13.52,
#   '2008-08': 14.48,
#   '2008-09': 60.41,
#   '2008-10': 35.68,
#   '2008-11': 56.77,
#   '2008-12': 64.25,
#   '2009-01': 86.23,
#   '2009-02': 116.5,
#   '2009-03': 104.36,
#   '2009-04': 75.32,
#   '2009-05': 61.62,
#   '2009-06': 37.54,
#   '2009-07': 41.49,
#   '2009-08': 12.15,
#   '2009-09': 50.09,
#   '2009-10': 47.41,
#   '2009-11': 87.11,
#   '2009-12': 103.28,
#   '2010-01': 127.28,
#   '2010-02': 90.08,
#   '2010-03': 73.35,
#   '2010-04': 79.22,
#   '2010-05': 55.33,
#   '2010-06': 67.5,
#   '2010-07': 22.44,
#   '2010-08': 8.96,
#   '2010-09': 22.36,
#   '2010-10': 103.26,
#   '2010-11': 13.81,
#   '2010-12': 94.47,
#   '2011-01': 70.73,
#   '2011-02': 67.3,
#   '2011-03': 71.71,
#   '2011-04': 122.83,
#   '2011-05': 95.09,
#   '2011-06': 52.85,
#   '2011-07': 21.84,
#   '2011-08': 16.87,
#   '2011-09': 25.32,
#   '2011-10': 67.5,
#   '2011-11': 39.99,
#   '2011-12': 64.76,
#   '2012-01': 128.47,
#   '2012-02': 102.61,
#   '2012-03': 64.3,
#   '2012-04': 54.91,
#   '2012-05': 91.1,
#   '2012-06': 28.47,
#   '2012-07': 21.24,
#   '2012-08': 24.27,
#   '2012-09': 11.72,
#   '2012-10': 52.13,
#   '2012-11': 66.93,
#   '2012-12': 136.72,
#   '2013-01': 101.42,
#   '2013-02': 76.08,
#   '2013-03': 72.17,
#   '2013-04': 67.11,
#   '2013-05': 59.33,
#   '2013-06': 31.24,
#   '2013-07': 14.98,
#   '2013-08': 10.99,
#   '2013-09': 24.5,
#   '2013-10': 51.04,
#   '2013-11': 50.55,
#   '2013-12': 42.8,
#   '2014-01': 59.73,
#   '2014-02': 27.77,
#   '2014-03': 84.99,
#   '2014-04': 60.22,
#   '2014-05': 78.03,
#   '2014-06': 58.31,
#   '2014-07': 21.35,
#   '2014-08': 22.01,
#   '2014-09': 66.72,
#   '2014-10': 70.69,
#   '2014-11': 64.52,
#   '2014-12': 90.35,
#   '2015-01': 98.07,
#   '2015-02': 97.4,
#   '2015-03': 109.98,
#   '2015-04': 77.3,
#   '2015-05': 70.3,
#   '2015-06': 75.37,
#   '2015-07': 9.14,
#   '2015-08': 27.98,
#   '2015-09': 27.81,
#   '2015-10': 85.5,
#   '2015-11': 42.72,
#   '2015-12': 24.71,
#   '2016-01': 131.29,
#   '2016-02': 62.93,
#   '2016-03': 89.35,
#   '2016-04': 42.25,
#   '2016-05': 95.29,
#   '2016-06': 46.07,
#   '2016-07': 18.65,
#   '2016-08': 23.61,
#   '2016-09': 36.98,
#   '2016-10': 26.42,
#   '2016-11': 51.92,
#   '2016-12': 105.06,
#   '2017-01': 87.85,
#   '2017-02': 20.35,
#   '2017-03': 79.97,
#   '2017-04': 78.86,
#   '2017-05': 91.14,
#   '2017-06': 43.2,
#   '2017-07': 14.9,
#   '2017-08': 23.9,
#   '2017-09': 14.79,
#   '2017-10': 51.9,
#   '2017-11': 63.6,
#   '2017-12': 74.45,
#   '2018-01': 97.32,
#   '2018-02': 64.67,
#   '2018-03': 84.96,
#   '2018-04': 29.38,
#   '2018-05': 107.48,
#   '2018-06': 55.95,
#   '2018-07': 22.71,
#   '2018-08': 17.11,
#   '2018-09': 27.17,
#   '2018-10': 68.75,
#   '2018-11': 71.64,
#   '2018-12': 142.86,
#   '2019-01': 137.63,
#   '2019-02': 64.99,
#   '2019-03': 76.96,
#   '2019-04': 89.37,
#   '2019-05': 50.3,
#   '2019-06': 57.69,
#   '2019-07': 25.26,
#   '2019-08': 21.03,
#   '2019-09': 20.65,
#   '2019-10': 29.38,
#   '2019-11': 37.34,
#   '2019-12': 106.09,
#   '2020-01': 82.2,
#   '2020-02': 97.4,
#   '2020-03': 87.92,
#   '2020-04': 67.52,
#   '2020-05': 77.22,
#   '2020-06': 44.56,
#   '2020-07': 15.85,
#   '2020-08': 13.42,
#   '2020-09': 10.7,
#   '2020-10': 23.49,
#   '2020-11': 41.66,
#   '2020-12': 48.52}}

# %%
# This function is a modified version of the function I used for the surface temperature data.
def get_monthly_precipitation(precipitation):
    keys = ['ALB', 'BIH', 'CYP', 'DZA', 'EGY', 'ESP', 'GRC', 'HRV', 'ISR', 'ITA', 'LBN', 'LBY', 'MAR', 'MCO', 'MLT', 'MNE', 'PSE', 'REU', 'SVN', 'SYR', 'TUN', 'TUR']
    monthly_averages = []
    for ticker in keys:
        country = precipitation[ticker]
        pr_list = list(country.values())
        for month in range(12):
            monthly_sum = sum(pr_list[month::12])  # Sum every 12th element (same month over 70 years)
            count = len(pr_list[month::12])  # Number of years
            monthly_average = monthly_sum / count  # Calculate average
            monthly_averages.append(((ticker, month, monthly_average)))
    return monthly_averages

# %%
# Calculate monthly precipitation for all countries
monthly_precipitation_averages = get_monthly_precipitation(pr)

# %%
MAPR_ = pd.DataFrame(monthly_precipitation_averages)

# %%
MAPR_
# Out:
#        0   1           2
# 0    ALB   0  133.161831
# 1    ALB   1  127.546901
# 2    ALB   2  121.285352
# 3    ALB   3  115.601690
# 4    ALB   4   95.322394
# ..   ...  ..         ...
# 259  TUR   7   19.795211
# 260  TUR   8   27.199718
# 261  TUR   9   52.508169
# 262  TUR  10   67.096761
# 263  TUR  11   85.124085
#
# [264 rows x 3 columns]

# %% [markdown]
# I am going to change the numbers in second column to month names for this dataframe too.

# %%
MAPR = MAPR_.replace(replace_dict)
MAPR
# Out:
#        0    1           2
# 0    ALB  Jan  133.161831
# 1    ALB  Feb  127.546901
# 2    ALB  Mar  121.285352
# 3    ALB  Apr  115.601690
# 4    ALB  May   95.322394
# ..   ...  ...         ...
# 259  TUR  Aug   19.795211
# 260  TUR  Sep   27.199718
# 261  TUR  Oct   52.508169
# 262  TUR  Nov   67.096761
# 263  TUR  Dec   85.124085
#
# [264 rows x 3 columns]

# %% [markdown]
# ## 3.

# %%
# (I wrote this function with the help of ChatGPT. I included the full session in my references.)

def get_average_temperature_per_annum(temperature):
    keys = ['ALB', 'BIH', 'CYP', 'DZA', 'EGY', 'ESP', 'GRC', 'HRV', 'ISR', 'ITA', 'LBN', 'LBY', 'MAR', 'MCO', 'MLT', 'MNE', 'PSE', 'REU', 'SVN', 'SYR', 'TUN', 'TUR']
    average_temperature_per_annum = {}

    for ticker in keys:
        country = temperature[ticker]
        temp_list = list(country.values())
        annual_averages = []
        for year in range(70):
            annual_sum = sum(temp_list[year * 12 : (year + 1) * 12])  # Sum temperatures for each month of the year
            annual_average = annual_sum / 12  # Calculate average for the year
            annual_averages.append(annual_average)
        average_temperature_per_annum[ticker] = annual_averages

    return average_temperature_per_annum

# %%
average_temperature_per_annum = get_average_temperature_per_annum(tas)

# %%
len(average_temperature_per_annum['TUR']) #the function returns 70 averages for 70 years.
# Out:
# 70

# %%
yast_list = list(average_temperature_per_annum.keys()) # average_temperature_per_annum is a dictionary. I get its keys and make a list

# %%
YAST = pd.DataFrame(average_temperature_per_annum, columns = yast_list) # I use the list as column names for the data frame.

# %%
YAST
# Out:
#           ALB        BIH        CYP        DZA        EGY        ESP  \
# 0   13.138333  10.496667  19.147500  21.981667  21.760000  13.560000
# 1   12.781667  10.160000  19.705833  22.313333  22.033333  12.445000
# 2   12.950833   9.658333  19.640000  22.205000  21.972500  12.763333
# 3   11.876667   9.070833  18.807500  21.635000  21.320000  12.970000
# 4   11.451667   8.340000  19.405000  21.374167  21.382500  12.646667
# ..        ...        ...        ...        ...        ...        ...
# 65  13.204167  10.953333  20.287500  23.890833  23.310833  14.810000
# 66  13.157500  10.732500  20.820833  24.712500  23.688333  14.593333
# 67  13.094167  10.596667  20.505833  24.146667  22.972500  15.045833
# 68  13.681667  11.174167  21.409167  24.168333  24.055833  14.180000
# 69  13.527500  11.351667  20.770833  24.010000  23.324167  14.583333
#
#           GRC        HRV        ISR        ITA  ...        MAR        MCO  \
# 0   15.106667  12.412500  19.250833  12.761667  ...  17.266667  13.175833
# 1   15.085833  12.240833  19.313333  12.246667  ...  16.969167  12.567500
# 2   15.458333  11.658333  19.502500  12.539167  ...  17.216667  12.940000
# 3   13.923333  11.145833  18.460000  12.245833  ...  16.710000  12.803333
# 4   13.977500  10.394167  19.154167  11.705833  ...  16.595000  12.390833
# ..        ...        ...        ...        ...  ...        ...        ...
# 65  15.210833  12.865833  20.367500  13.756667  ...  18.733333  14.695000
# 66  15.547500  12.525000  20.873333  13.567500  ...  18.980833  14.304167
# 67  15.206667  12.595833  20.548333  13.521667  ...  19.565000  14.302500
# 68  15.812500  13.144167  21.384167  13.840000  ...  17.927500  14.711667
# 69  15.752500  13.270833  20.641667  13.752500  ...  18.891667  14.605833
#
#           MLT        MNE        PSE        REU        SVN        SYR  \
# 0   19.591667   9.940833  18.785833  20.300000   9.779167  17.651667
# 1   18.953333   9.631667  19.095000  20.710000   9.766667  18.520000
# 2   19.455833   9.395833  19.062500  20.744167   8.825833  18.587500
# 3   18.669167   8.837500  18.012500  21.034167   8.898333  17.499167
# 4   18.165000   8.242500  18.761667  20.685000   8.215000  18.508333
# ..        ...        ...        ...        ...        ...        ...
# 65  19.569167  10.589167  19.791667  21.505833  10.865833  19.645000
# 66  19.694167  10.380833  20.306667  21.072500  10.535833  20.080833
# 67  19.490000  10.188333  20.002500  21.548333  10.546667  19.794167
# 68  19.768333  10.920000  20.820000  21.308333  11.104167  20.330833
# 69  19.530833  10.861667  20.017500  21.690000  11.243333  19.650833
#
#           TUN        TUR
# 0   18.560000  10.525000
# 1   18.640000  11.219167
# 2   19.341667  11.582500
# 3   18.274167  10.035000
# 4   17.935000  11.194167
# ..        ...        ...
# 65  20.310833  12.090000
# 66  20.983333  12.269167
# 67  20.118333  11.988333
# 68  20.565833  13.351667
# 69  20.390000  12.634167
#
# [70 rows x 22 columns]

# %% [markdown]
# ## 4.

# %%
# This function is a modified version of the function I used for the surface temperature data. 

def get_average_precipitation_per_annum(pr):
    keys = ['ALB', 'BIH', 'CYP', 'DZA', 'EGY', 'ESP', 'GRC', 'HRV', 'ISR', 'ITA', 'LBN', 'LBY', 'MAR', 'MCO', 'MLT', 'MNE', 'PSE', 'REU', 'SVN', 'SYR', 'TUN', 'TUR']
    average_precipitation_per_annum = {}

    for ticker in keys:
        country = pr[ticker]
        pr_list = list(country.values())
        annual_averages = []
        for year in range(70):
            annual_sum = sum(pr_list[year * 12 : (year + 1) * 12])  # Sum temperatures for each month of the year
            annual_average = annual_sum / 12  # Calculate average for the year
            annual_averages.append(annual_average)
        average_precipitation_per_annum[ticker] = annual_averages

    return average_precipitation_per_annum

# %%
average_precipitation_per_annum = get_average_precipitation_per_annum(tas)

# %%
startdate = datetime.datetime.strptime("2019-01-01", "%Y-%m-%d").date()
enddate = datetime.datetime.strptime("2022-12-31", "%Y-%m-%d").date()

# %%
stock = yf.download(["GOOG", "META", "CSCO", "INTC", "AMD", "QCOM", "AAPL", "005930.KS", "1810.HK", "TSLA"], start = startdate, end = enddate, group_by='tickers')
# Out:
# [*********************100%%**********************]  10 of 10 completed

# %% [markdown]
# Cleaning the data. I dropped the null values in each company's data with the function below.

# %%
# (I had the main idea and the structure of the function, I asked ChatGPT to help me with the rest.
# I shared the full session below in my References list.)

def clean_company_data(dataframe):
    company = ["GOOG", "META", "CSCO", "INTC", "AMD", "QCOM", "AAPL", "005930.KS", "1810.HK", "TSLA"]
    dataframe_new = {}
    # Loop through each company ticker and drop null values for that specific column
    for i in range(len(company)):
        dataframe_new[company[i]] = dataframe[company[i]].dropna()
    
    # Return the cleaned DataFrame
    return dataframe_new

# %%
cleaned_stock_data = clean_company_data(stock)

# %% [markdown]
# ## 1.

# %% [markdown]
# This function takes the opening and closing values of each company and calculates the values.

# %%
# (I had the main idea and the structure of the function. I wrote the function as best as I could,
# then I asked ChatGPT to help me with the rest.
# I shared the full session below in my References list.)

def get_change(stock):
    company = ["GOOG", "META", "CSCO", "INTC", "AMD", "QCOM", "AAPL", "005930.KS", "1810.HK", "TSLA"]
    results = {}  # Dictionary to store results for each company
    
    for ticker in company:
        results[ticker] = []
        for index, row in stock[ticker].iterrows():
            a = row['Open'] + row['Open'] * 0.025
            b = row['Open'] + row['Open'] * -0.025
            
            if (row['Close'] >= b) and (row['Close'] <= a):
                results[ticker].append(0)
            elif row['Close'] > a:
                results[ticker].append(1)
            else:
                results[ticker].append(-1)
    
    return results

# %%
results = get_change(cleaned_stock_data)

# %%
type(results)
# Out:
# dict

# %% [markdown]
# This function gets the dates from the data as indices for the change results we found.

# %%
#(ChatGPT wrote this function for me, I only modified a couple of things. 
# I shared the full session below in my References list.)

def create_results_dataframes(results, cleaned_stock_data):
    company_dataframes = {}  # Dictionary to store DataFrames for each company
    
    for ticker, values in results.items():
        # Extract dates from the original DataFrame (assuming 'Date' is the column name)
        dates = cleaned_stock_data[ticker].index
        
        # Create a DataFrame for the current company with dates as indices and change values as columns
        company_df = pd.DataFrame({'Date': dates, 'Values': values})
        
        # Set 'Date' column as index
        company_df.set_index('Date', inplace=True)
        
        # Add the DataFrame to the dictionary with the ticker symbol as the key
        company_dataframes[ticker] = company_df
    
    return company_dataframes

# %%
CHANGE = create_results_dataframes(results, cleaned_stock_data) 
# This is a dictionary. I couldn't turn it to a dataframe because the number of the rows aren't the same for each company
# since I only worked with the non-null values.

# %% [markdown]
# ## 2.

# %% [markdown]
# This function finds the longest continuous time intervals that 'change' values of the companies remain 1 and -1.

# %%
#(ChatGPT wrote this function for me, I only modified a couple of things. 
# I shared the full session below in my References list.)

def find_longest_intervals(data_dict, target_values):
    longest_intervals = {}

    for ticker, df in data_dict.items():
        for target_value in target_values:
            longest_interval_start = None
            longest_interval_end = None
            current_interval_start = None
            max_interval_length = 0

            for index, row in df.iterrows():
                if row['Values'] == target_value:
                    if current_interval_start is None:
                        current_interval_start = index

                    current_interval_end = index
                else:
                    if current_interval_start is not None:
                        interval_length = (current_interval_end - current_interval_start).days + 1
                        if interval_length > max_interval_length:
                            max_interval_length = interval_length
                            longest_interval_start = current_interval_start
                            longest_interval_end = current_interval_end

                        current_interval_start = None

            if current_interval_start is not None:
                interval_length = (current_interval_end - current_interval_start).days + 1
                if interval_length > max_interval_length:
                    longest_interval_start = current_interval_start
                    longest_interval_end = current_interval_end

            if ticker not in longest_intervals:
                longest_intervals[ticker] = {}

            longest_intervals[ticker][target_value] = (longest_interval_start, longest_interval_end)

    return longest_intervals

# %%
target_values = [1, -1]
longest_intervals = find_longest_intervals(CHANGE, target_values)

# %%
company = ["GOOG", "META", "CSCO", "INTC", "AMD", "QCOM", "AAPL", "005930.KS", "1810.HK", "TSLA"]
print('Longest intervals for')
for i in company:

    print(i)
    print(longest_intervals[i])
    print('\n')
# Out:
# Longest intervals for
# GOOG
# {1: (Timestamp('2020-02-28 00:00:00'), Timestamp('2020-03-02 00:00:00')), -1: (Timestamp('2022-03-11 00:00:00'), Timestamp('2022-03-14 00:00:00'))}
#
#
# META
# {1: (Timestamp('2022-11-10 00:00:00'), Timestamp('2022-11-14 00:00:00')), -1: (Timestamp('2022-06-09 00:00:00'), Timestamp('2022-06-13 00:00:00'))}
#
#
# CSCO
# {1: (Timestamp('2020-02-28 00:00:00'), Timestamp('2020-03-02 00:00:00')), -1: (Timestamp('2020-03-20 00:00:00'), Timestamp('2020-03-23 00:00:00'))}
#
#
# INTC
# {1: (Timestamp('2022-11-10 00:00:00'), Timestamp('2022-11-11 00:00:00')), -1: (Timestamp('2022-09-02 00:00:00'), Timestamp('2022-09-06 00:00:00'))}
#
#
# AMD
# {1: (Timestamp('2021-07-28 00:00:00'), Timestamp('2021-08-04 00:00:00')), -1: (Timestamp('2022-06-08 00:00:00'), Timestamp('2022-06-13 00:00:00'))}
#
#
# QCOM
# {1: (Timestamp('2022-05-25 00:00:00'), Timestamp('2022-05-31 00:00:00')), -1: (Timestamp('2019-08-23 00:00:00'), Timestamp('2019-08-26 00:00:00'))}
#
#
# AAPL
# {1: (Timestamp('2020-02-28 00:00:00'), Timestamp('2020-03-02 00:00:00')), -1: (Timestamp('2020-09-02 00:00:00'), Timestamp('2020-09-03 00:00:00'))}
#
#
# 005930.KS
# {1: (Timestamp('2020-11-13 00:00:00'), Timestamp('2020-11-16 00:00:00')), -1: (Timestamp('2020-03-18 00:00:00'), Timestamp('2020-03-19 00:00:00'))}
#
#
# 1810.HK
# {1: (Timestamp('2020-07-02 00:00:00'), Timestamp('2020-07-06 00:00:00')), -1: (Timestamp('2022-11-11 00:00:00'), Timestamp('2022-11-14 00:00:00'))}
#
#
# TSLA
# {1: (Timestamp('2022-10-21 00:00:00'), Timestamp('2022-10-25 00:00:00')), -1: (Timestamp('2021-03-02 00:00:00'), Timestamp('2021-03-08 00:00:00'))}

# %% [markdown]
# ## 3.

# %%
# (I had the main idea and the structure of the function. I wrote the function as best as I could,
# then I asked ChatGPT to help me with the rest.
# I shared the full session below in my References list.)


def get_difference(dictionary):
    company = ["GOOG", "META", "CSCO", "INTC", "AMD", "QCOM", "AAPL", "005930.KS", "1810.HK", "TSLA"]
    differences = {} 
    
    for i in company:
        differences[i] = []
        # Start iterating from the second row (index 1)
        for index in range(1, len(dictionary[i])):
            # Get the opening price of the current row
            current_open = dictionary[i]['Open'].iloc[index]
            
            # Get the opening price of the previous day (shifted one row up)
            previous_open = dictionary[i]['Open'].iloc[index - 1]
            
            # Calculate the thresholds
            lower_threshold = previous_open * -0.025 + previous_open
            upper_threshold = previous_open * 0.025 + previous_open
            
            # Determine the difference based on the relationship with the previous day's opening price
            if (current_open <= upper_threshold) and (current_open >= lower_threshold):
                differences[i].append(0)
            elif current_open >= upper_threshold:
                differences[i].append(1)
            else:
                differences[i].append(-1)
    return differences

# %%
differences = get_difference(cleaned_stock_data)

# %%
# This is the same function as the one I used to get the CHANGE dataframes.
# I only made a few litte modifications to fit this question (with the help of chatGPT.)

def create_differences_dataframes(differences, cleaned_stock_data):
    company_dataframes = {}  # Dictionary to store DataFrames for each company
    
    for ticker, values in differences.items():
        # Exclude the first row from cleaned_stock_data to match differences length
        stock_data_subset = cleaned_stock_data[ticker][1:]
        
        dates = stock_data_subset.index
        
        # Create a DataFrame for the current company with dates as indices and change values as columns
        company_df = pd.DataFrame({'Date': dates, 'Values': values})
        
        # Set 'Date' column as index
        company_df.set_index('Date', inplace=True)
        
        # Add the DataFrame to the dictionary with the ticker symbol as the key
        company_dataframes[ticker] = company_df
    
    return company_dataframes

# %%
DIFFERENCE = create_differences_dataframes(differences, cleaned_stock_data)
# This is a dictionary. I couldn't turn it to a dataframe because the number of the rows aren't the same for each company
# since I only worked with the non-null values.

# %% [markdown]
# ## 4.

# %%
# This is the same function as the one I used to get the longest intervals for CHANGE.
def get_longest_intervals(data_dict, target_values):
    longest_intervals = {}

    for ticker, df in data_dict.items():
        for target_value in target_values:
            longest_interval_start = None
            longest_interval_end = None
            current_interval_start = None
            max_interval_length = 0

            for index, row in df.iterrows():
                if row['Values'] == target_value:
                    if current_interval_start is None:
                        current_interval_start = index

                    current_interval_end = index
                else:
                    if current_interval_start is not None:
                        interval_length = (current_interval_end - current_interval_start).days + 1
                        if interval_length > max_interval_length:
                            max_interval_length = interval_length
                            longest_interval_start = current_interval_start
                            longest_interval_end = current_interval_end

                        current_interval_start = None

            if current_interval_start is not None:
                interval_length = (current_interval_end - current_interval_start).days + 1
                if interval_length > max_interval_length:
                    longest_interval_start = current_interval_start
                    longest_interval_end = current_interval_end

            if ticker not in longest_intervals:
                longest_intervals[ticker] = {}

            longest_intervals[ticker][target_value] = (longest_interval_start, longest_interval_end)

    return longest_intervals

# %%
target_values = [1, -1]
longest_intervals_for_difference = get_longest_intervals(DIFFERENCE, target_values)

# %%
company = ["GOOG", "META", "CSCO", "INTC", "AMD", "QCOM", "AAPL", "005930.KS", "1810.HK", "TSLA"]
for i in company:
    print('Longest intervals for')
    print(i)
    print(longest_intervals_for_difference[i])
    print('\n')
# Out:
# Longest intervals for
# GOOG
# {1: (Timestamp('2022-05-27 00:00:00'), Timestamp('2022-05-31 00:00:00')), -1: (Timestamp('2020-09-04 00:00:00'), Timestamp('2020-09-08 00:00:00'))}
#
#
# Longest intervals for
# META
# {1: (Timestamp('2022-06-24 00:00:00'), Timestamp('2022-06-27 00:00:00')), -1: (Timestamp('2020-09-04 00:00:00'), Timestamp('2020-09-08 00:00:00'))}
#
#
# Longest intervals for
# CSCO
# {1: (Timestamp('2021-05-07 00:00:00'), Timestamp('2021-05-10 00:00:00')), -1: (Timestamp('2019-08-02 00:00:00'), Timestamp('2019-08-05 00:00:00'))}
#
#
# Longest intervals for
# INTC
# {1: (Timestamp('2020-04-03 00:00:00'), Timestamp('2020-04-07 00:00:00')), -1: (Timestamp('2020-09-04 00:00:00'), Timestamp('2020-09-08 00:00:00'))}
#
#
# Longest intervals for
# AMD
# {1: (Timestamp('2022-11-10 00:00:00'), Timestamp('2022-11-15 00:00:00')), -1: (Timestamp('2019-07-30 00:00:00'), Timestamp('2019-08-05 00:00:00'))}
#
#
# Longest intervals for
# QCOM
# {1: (Timestamp('2020-01-17 00:00:00'), Timestamp('2020-01-21 00:00:00')), -1: (Timestamp('2020-09-04 00:00:00'), Timestamp('2020-09-08 00:00:00'))}
#
#
# Longest intervals for
# AAPL
# {1: (Timestamp('2022-05-27 00:00:00'), Timestamp('2022-05-31 00:00:00')), -1: (Timestamp('2020-09-03 00:00:00'), Timestamp('2020-09-08 00:00:00'))}
#
#
# Longest intervals for
# 005930.KS
# {1: (Timestamp('2019-01-24 00:00:00'), Timestamp('2019-01-25 00:00:00')), -1: (Timestamp('2020-03-19 00:00:00'), Timestamp('2020-03-23 00:00:00'))}
#
#
# Longest intervals for
# 1810.HK
# {1: (Timestamp('2020-07-03 00:00:00'), Timestamp('2020-07-07 00:00:00')), -1: (Timestamp('2022-05-06 00:00:00'), Timestamp('2022-05-10 00:00:00'))}
#
#
# Longest intervals for
# TSLA
# {1: (Timestamp('2020-06-30 00:00:00'), Timestamp('2020-07-07 00:00:00')), -1: (Timestamp('2019-01-18 00:00:00'), Timestamp('2019-01-24 00:00:00'))}

# %% [markdown]
# ## References
# - https://climateknowledgeportal.worldbank.org/download-data#
# - https://stackoverflow.com/questions/22100130/pandas-replace-multiple-values-one-column
# - https://stackoverflow.com/questions/68373763/yfinance-setting-my-end-date-to-2021-1-1-but-the-end-date-for-the-data-becomes
# - https://pypi.org/project/yfinance/
# - https://algotrading101.com/learn/yfinance-guide/
# - https://stackoverflow.com/questions/49586471/add-new-column-to-python-pandas-dataframe-based-on-multiple-conditions
# - https://sparkbyexamples.com/pandas/pandas-set-index-name-to-dataframe/#:~:text=Alternatively%2C%20index%20name%20can%20be,index.
#
# #### CHATGPT
# - https://chat.openai.com/share/6629f584-d9f6-4249-92bf-58ec5d3a9db8
